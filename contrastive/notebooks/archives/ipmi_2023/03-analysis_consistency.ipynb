# %% [markdown]
# Notebook where the nn distance is correlated to the auc_std. Should be used for
# all analysis meant to know about a model consistency in its embeddings generation.

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from contrastive.utils.models_database import import_bdd

# %%
bdd = import_bdd()
bdd
# Out:
#                                             model_path  ...      git_branch
# 116  /neurospin/dico/agaudin/Runs/04_pointnet/Outpu...  ...        pointnet
# 75   /neurospin/dico/agaudin/Runs/04_pointnet/Outpu...  ...  Run_03_aymeric
# 25   /neurospin/dico/agaudin/Runs/03_monkeys/Output...  ...  Run_03_aymeric
# 91   /neurospin/dico/agaudin/Runs/04_pointnet/Outpu...  ...        pointnet
# 12   /neurospin/dico/agaudin/Runs/03_monkeys/Output...  ...  Run_03_aymeric
# ..                                                 ...  ...             ...
# 39   /neurospin/dico/agaudin/Runs/03_monkeys/Output...  ...  Run_03_aymeric
# 100  /neurospin/dico/agaudin/Runs/04_pointnet/Outpu...  ...        pointnet
# 19   /neurospin/dico/agaudin/Runs/03_monkeys/Output...  ...  Run_03_aymeric
# 38   /neurospin/dico/agaudin/Runs/03_monkeys/Output...  ...  Run_03_aymeric
# 129  /neurospin/dico/agaudin/Runs/04_pointnet/Outpu...  ...        pointnet
#
# [110 rows x 24 columns]

# %%
nn_measured = bdd[bdd.model_path.str.contains("/neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders")]
nn_measured
# Out:
#                                            model_path  ...      git_branch
# 25  /neurospin/dico/agaudin/Runs/03_monkeys/Output...  ...  Run_03_aymeric
# 12  /neurospin/dico/agaudin/Runs/03_monkeys/Output...  ...  Run_03_aymeric
# 24  /neurospin/dico/agaudin/Runs/03_monkeys/Output...  ...  Run_03_aymeric
# 31  /neurospin/dico/agaudin/Runs/03_monkeys/Output...  ...  Run_03_aymeric
# 23  /neurospin/dico/agaudin/Runs/03_monkeys/Output...  ...  Run_03_aymeric
# 13  /neurospin/dico/agaudin/Runs/03_monkeys/Output...  ...  Run_03_aymeric
# 2   /neurospin/dico/agaudin/Runs/03_monkeys/Output...  ...  Run_03_aymeric
# 6   /neurospin/dico/agaudin/Runs/03_monkeys/Output...  ...  Run_03_aymeric
# 11  /neurospin/dico/agaudin/Runs/03_monkeys/Output...  ...  Run_03_aymeric
# 15  /neurospin/dico/agaudin/Runs/03_monkeys/Output...  ...  Run_03_aymeric
# 26  /neurospin/dico/agaudin/Runs/03_monkeys/Output...  ...  Run_03_aymeric
# 36  /neurospin/dico/agaudin/Runs/03_monkeys/Output...  ...  Run_03_aymeric
# 14  /neurospin/dico/agaudin/Runs/03_monkeys/Output...  ...  Run_03_aymeric
# 22  /neurospin/dico/agaudin/Runs/03_monkeys/Output...  ...  Run_03_aymeric
# 7   /neurospin/dico/agaudin/Runs/03_monkeys/Output...  ...  Run_03_aymeric
# 4   /neurospin/dico/agaudin/Runs/03_monkeys/Output...  ...  Run_03_aymeric
# 3   /neurospin/dico/agaudin/Runs/03_monkeys/Output...  ...  Run_03_aymeric
# 1   /neurospin/dico/agaudin/Runs/03_monkeys/Output...  ...  Run_03_aymeric
# 28  /neurospin/dico/agaudin/Runs/03_monkeys/Output...  ...  Run_03_aymeric
# 0   /neurospin/dico/agaudin/Runs/03_monkeys/Output...  ...  Run_03_aymeric
# 32  /neurospin/dico/agaudin/Runs/03_monkeys/Output...  ...  Run_03_aymeric
# 5   /neurospin/dico/agaudin/Runs/03_monkeys/Output...  ...  Run_03_aymeric
# 17  /neurospin/dico/agaudin/Runs/03_monkeys/Output...  ...  Run_03_aymeric
# 10  /neurospin/dico/agaudin/Runs/03_monkeys/Output...  ...  Run_03_aymeric
# 33  /neurospin/dico/agaudin/Runs/03_monkeys/Output...  ...  Run_03_aymeric
# 35  /neurospin/dico/agaudin/Runs/03_monkeys/Output...  ...  Run_03_aymeric
# 27  /neurospin/dico/agaudin/Runs/03_monkeys/Output...  ...  Run_03_aymeric
# 34  /neurospin/dico/agaudin/Runs/03_monkeys/Output...  ...  Run_03_aymeric
# 21  /neurospin/dico/agaudin/Runs/03_monkeys/Output...  ...  Run_03_aymeric
# 29  /neurospin/dico/agaudin/Runs/03_monkeys/Output...  ...  Run_03_aymeric
# 40  /neurospin/dico/agaudin/Runs/03_monkeys/Output...  ...  Run_03_aymeric
# 41  /neurospin/dico/agaudin/Runs/03_monkeys/Output...  ...  Run_03_aymeric
# 39  /neurospin/dico/agaudin/Runs/03_monkeys/Output...  ...  Run_03_aymeric
# 19  /neurospin/dico/agaudin/Runs/03_monkeys/Output...  ...  Run_03_aymeric
# 38  /neurospin/dico/agaudin/Runs/03_monkeys/Output...  ...  Run_03_aymeric
#
# [35 rows x 24 columns]

# %%
nn_dist = pd.read_csv("/neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/#performance_comparisons/nn/nne_ln.csv", index_col=0)
nn_dist
# Out:
#                   convnet  densenet2
# foldlabel_30     0.433729   0.596620
# foldlabel_4      0.783451   0.731105
# no_foldlabel_30  0.324525   0.422612
# no_foldlabel_4   0.849684   0.750240

# %%
parameters = ['backbone_name','foldlabel','num_representation_features']

# %%
std_values = nn_measured.groupby(parameters).auc_std.mean()
#print(std_values)


std_df = np.zeros((4,2))
std_df[:,0] = std_values['convnet'][::-1]
std_df[:,1] = std_values['densenet'][::-1]


std_df = pd.DataFrame(std_df, columns=nn_dist.columns, index=nn_dist.index)
std_df
# Out:
# backbone_name  foldlabel  num_representation_features
# convnet        False      4                              0.042906
#                           30                             0.044261
#                True       4                              0.046497
#                           30                             0.044489
# densenet       False      4                              0.029519
#                           30                             0.038345
#                True       4                              0.032754
#                           30                             0.049897
# Name: auc_std, dtype: float64
#                   convnet  densenet2
# foldlabel_30     0.044489   0.049897
# foldlabel_4      0.046497   0.032754
# no_foldlabel_30  0.044261   0.038345
# no_foldlabel_4   0.042906   0.029519

# %%
## same thing but with auc
auc_values = nn_measured.groupby(parameters).auc.mean()
#print(auc_values)


auc_df = np.zeros((4,2))
auc_df[:,0] = auc_values['convnet'][::-1]
auc_df[:,1] = auc_values['densenet'][::-1]


auc_df = pd.DataFrame(auc_df, columns=nn_dist.columns, index=nn_dist.index)
auc_df
# Out:
#                   convnet  densenet2
# foldlabel_30     0.613729   0.658608
# foldlabel_4      0.606950   0.583352
# no_foldlabel_30  0.649748   0.575910
# no_foldlabel_4   0.522667   0.483569

# %%
plt.scatter(nn_dist.values.flatten(), std_df.values.flatten())
plt.xlabel("nn distance")
plt.ylabel("Std auc")
plt.show()

plt.scatter(nn_dist.values.flatten(), auc_df.values.flatten())
plt.xlabel("nn distance")
plt.ylabel("auc")
plt.show()

# %% [markdown]
# ## Pointnet

# %%
pointnets = bdd[bdd.backbone_name == 'pointnet']
repeat_pointnets = pointnets[pointnets.model_path.str.contains('file')]
repeat_pointnets
# Out:
#                                             model_path  ...  git_branch
# 91   /neurospin/dico/agaudin/Runs/04_pointnet/Outpu...  ...    pointnet
# 105  /neurospin/dico/agaudin/Runs/04_pointnet/Outpu...  ...    pointnet
# 87   /neurospin/dico/agaudin/Runs/04_pointnet/Outpu...  ...    pointnet
# 90   /neurospin/dico/agaudin/Runs/04_pointnet/Outpu...  ...    pointnet
# 88   /neurospin/dico/agaudin/Runs/04_pointnet/Outpu...  ...    pointnet
# 92   /neurospin/dico/agaudin/Runs/04_pointnet/Outpu...  ...    pointnet
# 98   /neurospin/dico/agaudin/Runs/04_pointnet/Outpu...  ...    pointnet
# 95   /neurospin/dico/agaudin/Runs/04_pointnet/Outpu...  ...    pointnet
# 104  /neurospin/dico/agaudin/Runs/04_pointnet/Outpu...  ...    pointnet
# 112  /neurospin/dico/agaudin/Runs/04_pointnet/Outpu...  ...    pointnet
# 96   /neurospin/dico/agaudin/Runs/04_pointnet/Outpu...  ...    pointnet
# 89   /neurospin/dico/agaudin/Runs/04_pointnet/Outpu...  ...    pointnet
# 102  /neurospin/dico/agaudin/Runs/04_pointnet/Outpu...  ...    pointnet
# 94   /neurospin/dico/agaudin/Runs/04_pointnet/Outpu...  ...    pointnet
# 111  /neurospin/dico/agaudin/Runs/04_pointnet/Outpu...  ...    pointnet
# 97   /neurospin/dico/agaudin/Runs/04_pointnet/Outpu...  ...    pointnet
# 110  /neurospin/dico/agaudin/Runs/04_pointnet/Outpu...  ...    pointnet
# 99   /neurospin/dico/agaudin/Runs/04_pointnet/Outpu...  ...    pointnet
# 93   /neurospin/dico/agaudin/Runs/04_pointnet/Outpu...  ...    pointnet
# 109  /neurospin/dico/agaudin/Runs/04_pointnet/Outpu...  ...    pointnet
# 108  /neurospin/dico/agaudin/Runs/04_pointnet/Outpu...  ...    pointnet
# 107  /neurospin/dico/agaudin/Runs/04_pointnet/Outpu...  ...    pointnet
# 101  /neurospin/dico/agaudin/Runs/04_pointnet/Outpu...  ...    pointnet
# 106  /neurospin/dico/agaudin/Runs/04_pointnet/Outpu...  ...    pointnet
# 103  /neurospin/dico/agaudin/Runs/04_pointnet/Outpu...  ...    pointnet
# 100  /neurospin/dico/agaudin/Runs/04_pointnet/Outpu...  ...    pointnet
#
# [26 rows x 24 columns]

# %%
main_path = "/neurospin/dico/agaudin/Runs/04_pointnet/Output/pointnet"
folders = [folder for folder in os.listdir(main_path)
           if 'file' in folder]

nn_means = []
auc_stds = []

for folder in folders:
    auc_stds.append(pointnets[pointnets.model_path.str.contains(main_path+'/'+folder)].auc_std.mean())
    with open(main_path+'/'+folder+'/#nn/mean_nn.txt', 'r') as file:
        nne = file.readline()
        nn_means.append(float(nne))

# %%
for i in range(len(folders)):
    print(folders[i], nn_means[i])
# Out:
# file_fold_4_drop_rate=0.05_HCPfull 0.5946846447888086
# file_fold_30_drop_rate=0.05_HCPfull 0.43847828037491465
# file_fold_4_drop_rate=0.05 0.6933971041647385
# file_no_30_drop_rate=0.05 0.44561359329634254
# file_no_30 0.6433180418532796
# file_fold_30_drop_rate=0.05 0.4395491986444514

# %%
plt.scatter(nn_means, auc_stds)
plt.xlabel("nn distance")
plt.ylabel("Std auc")
plt.show()

# %%
# porque no los dos?

plt.scatter(nn_dist.values.flatten(), std_df.values.flatten())
plt.scatter(nn_means, auc_stds, marker='^')
plt.xlabel("nn distance")
plt.ylabel("Std auc")
plt.show()
