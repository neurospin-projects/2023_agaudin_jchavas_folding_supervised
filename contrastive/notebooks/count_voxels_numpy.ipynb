# %%
import os

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

pd.options.display.max_rows = 20

# %% [markdown]
# # UKB

# %%
path2crop = "/neurospin/dico/data/deep_folding/current/datasets/UkBioBank/crops/2mm/CINGULATE/mask/"

# %%
skel = np.load(f"{path2crop}Lskeleton.npy")

# %%
np.unique(skel)
# Out:
# array([  0,  30,  35,  60, 100, 120], dtype=int16)

# %%
skel.shape
# Out:
# (21052, 18, 41, 38, 1)

# %%
(skel!=0).sum()
# Out:
# 15734836

# %%
count_skel = (skel!=0).sum(axis=(1,2,3,4))

# %%
p = plt.hist(count_skel, bins=100)

# %%
fold = np.load(f"{path2crop}Llabel.npy")

# %%
fold.shape
# Out:
# (21052, 18, 41, 38, 1)

# %%
(fold!=0).sum()
# Out:
# 15734836

# %%
count_fold = (fold!=0).sum(axis=(1,2,3,4))

# %%
pf = plt.hist(count_fold, bins=100)

# %%
if ((skel!=0)*(fold==0)).sum()==0:
    print("OK: skeleton crops and foldlabel crops span the same voxels")
else:
    print("ERROR: skeleton crops and foldlabel crops are not included one in the other")
# Out:
# OK: skeleton crops and foldlabel crops span the same voxels
