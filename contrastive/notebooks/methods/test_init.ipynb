# %% [markdown]
# Checks the influence of weight initialisation on performance.

# %%
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
bdd = pd.read_csv("/neurospin/dico/agaudin/Runs/09_new_repo/Output/init_test/bdd_init_diff.csv", index_col=0)

bdd["init"] = bdd.model_path.str.contains("manual")

bdd
# Out:
#                                            model_path  train_auc   val_auc  \
# 0   /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.695566  0.582952
# 1   /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.592955  0.508108
# 2   /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.935862  0.612474
# 3   /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.758024  0.627859
# 4   /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.946286  0.580873
# 5   /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.705924  0.597089
# 6   /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.991973  0.548857
# 7   /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.990926  0.568815
# 8   /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.991918  0.518503
# 9   /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.931907  0.484823
# 10  /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.890571  0.550520
# ...

# %%
sns.barplot(bdd, x="init", y="best_train_auc")
plt.show()
sns.barplot(bdd, x="init", y="best_val_auc")
plt.show()
sns.barplot(bdd, x="init", y="best_test_intra_auc")
plt.show()
sns.barplot(bdd, x="init", y="best_test_auc")
plt.show()
