# %%
import os

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

pd.options.display.max_rows = 20
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
from soma.aims.lazy_read_data import LazyReadData
from soma import aims
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from soma.aims.lazy_read_data import LazyReadData
#       2 from soma import aims
#
# ModuleNotFoundError: No module named 'soma'

# %%
def count_voxels(data_dir_path, dtype='skel'):
    count_voxels_dict = {}

    j = 0
    for i,file in enumerate(os.listdir(data_dir_path)):
        if file.endswith(".nii.gz"):
            subject_name = file
            if dtype == 'skel':
                subject_name = subject_name.replace("resampled_skeleton_", "")
                subject_name = subject_name[1:-7]
            elif dtype == 'crop':
                subject_name = subject_name.replace("_cropped_skeleton", "")
                subject_name = subject_name[:-7]
            else:
                print("Unknown dtype")
            print(j, subject_name)
            j = j+1
            
            file_path = os.path.join(data_dir_path, file)

            # get the array thanks to aims
            vol = aims.read(file_path)

            arr = np.asarray(vol)

            count = np.count_nonzero(arr)

            count_voxels_dict[subject_name] = count

    count_df = pd.DataFrame.from_dict(count_voxels_dict, orient='index', columns=["count"])

    # count_df = count_df.sort_values(by='count')

    return count_df

# %% [markdown]
# # HCP

# %%
path2crops = "/neurospin/dico/data/deep_folding/current/datasets/hcp/crops/2mm/CINGULATE/mask/Rcrops"
count_df = count_voxels(path2crops, dtype='crop')

count_df.head()
# Out:
# 0 141119
# 1 715647
# 2 889579
# 3 782157
# 4 827052
# 5 843151
# 6 217126
# 7 228434
# 8 704238
# 9 205119
# 10 128935
# 11 792564
# 12 127226
# 13 880157
# 14 959574
# 15 688569
# 16 163129
# 17 351938
# 18 135932
# 19 161327
# 20 308129
# 21 146735
# 22 904044
# 23 119126
# 24 162733
# 25 158035
# 26 994273
# 27 223929
# 28 513736
# 29 573451
# 30 804646
# 31 171431
# 32 119025
# 33 115825
# 34 350330
# 35 679770
# 36 211114
# 37 626648
# 38 140117
# 39 826454
# 40 690152
# 41 449753
# 42 129634
# 43 825048
# 44 185442
# 45 200109
# 46 599671
# 47 199251
# 48 667056
# 49 173839
# 50 580044
# 51 200210
# 52 376247
# 53 568963
# 54 214726
# 55 314225
# 56 109325
# 57 686969
# 58 133625
# 59 188751
# 60 150928
# 61 165234
# 62 115724
# 63 124220
# 64 355239
# 65 192035
# 66 178950
# 67 627852
# 68 173536
# 69 268749
# 70 680452
# 71 122620
# 72 957974
# 73 181636
# 74 131823
# 75 164939
# 76 766563
# 77 175035
# 78 609143
# 79 175439
# 80 210011
# 81 541640
# 82 298051
# 83 201111
# 84 144125
# 85 153126
# 86 933253
# 87 705341
# 88 236130
# 89 580751
# 90 429040
# 91 299154
# 92 521331
# 93 713239
# 94 119833
# 95 644044
# 96 237334
# 97 735148
# 98 144832
# 99 197550
# 100 687163
# 101 978578
# 102 130720
# 103 102513
# 104 156435
# 105 317332
# 106 570243
# 107 125525
# 108 594156
# 109 191033
# 110 552544
# 111 148335
# 112 151627
# 113 183337
# 114 316835
# 115 206525
# 116 185038
# 117 204218
# 118 115017
# 119 174841
# 120 200917
# 121 953764
# 122 519950
# 123 549757
# 124 115320
# 125 522434
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 np.random.permutation(count_df['nb_voxels'].values)
#
# NameError: name 'count_df' is not defined

# %% [markdown]
# # UKB

# %%
path2rescaled_skels = "/neurospin/dico/data/deep_folding/current/datasets/UkBioBank/skeletons/2mm/R"

# %%
count_df = count_voxels(path2rescaled_skels)

count_df
# Out:
# 1 sub-3297409
# 3 sub-1480046
# 6 sub-3223524
# 7 sub-2728307
# 9 sub-1489596
# 13 sub-1722907
# 14 sub-5391046
# 16 sub-2541165
# 17 sub-3783118
# 19 sub-1124947
# 25 sub-5254638
# 31 sub-2178551
# 33 sub-1187029
# 34 sub-1482545
# 39 sub-5086299
# 45 sub-5925506
# 46 sub-5020679
# 47 sub-1426174
# 48 sub-1241484
# 51 sub-1002986
# 53 sub-1080689
# 54 sub-1904930
# 60 sub-3542532
# 64 sub-5456712
# 67 sub-3997832
# 69 sub-5344468
# 71 sub-2953677
# 72 sub-4473479
# 73 sub-3411481
# 74 sub-4822299
# 78 sub-3351746
# 80 sub-2945280
# 82 sub-1674647
# 86 sub-4518174
# 87 sub-1691195
# 89 sub-3818231
# 90 sub-3025491
# 92 sub-3923377
# 93 sub-5331137
# 94 sub-1904912
# 96 sub-5360604
# 99 sub-5925530
# 103 sub-2528797
# 105 sub-5907151
# 106 sub-1261809
# 107 sub-3708600
# 108 sub-3567315
# 110 sub-2545591
# 111 sub-3976006
# 112 sub-2344898
# 113 sub-2729106
# 116 sub-1249508
# 117 sub-1774544
# 118 sub-1185514
# 119 sub-1881442
# 120 sub-5062606
# 121 sub-5847605
# 125 sub-5356222
# 126 sub-5495473
# 127 sub-4588275
# 130 sub-2122201
# 131 sub-2582656
# 132 sub-2905339
# 133 sub-3755982
# 134 sub-4589882
# 138 sub-2161405
# 140 sub-2277806
# 143 sub-1470638
# 144 sub-3951768
# 145 sub-2302991
# 146 sub-1898872
# 147 sub-3313116
# 152 sub-2401548
# 158 sub-1197764
# 160 sub-2844271
# 162 sub-2278120
# 165 sub-2296470
# 167 sub-4816653
# 168 sub-2405504
# 169 sub-2247652
# 171 sub-1902905
# 172 sub-4125811
# 176 sub-4595809
# 177 sub-4808163
# 179 sub-1962315
# 180 sub-5080095
# 181 sub-1535763
# 183 sub-3333583
# 184 sub-3773427
# 186 sub-5936783
# 188 sub-3665529
# 189 sub-4636671
# 190 sub-1178192
# 192 sub-1504538
# 194 sub-1467240
# 195 sub-5861176
# 200 sub-1217108
# 201 sub-4773382
# 207 sub-1863557
# 208 sub-3113505
# 209 sub-2870369
# 213 sub-4504827
# 216 sub-1656533
# 217 sub-3876211
# 218 sub-5250178
# 227 sub-5881724
# 229 sub-2843663
# 233 sub-5737976
# 236 sub-2488326
# 237 sub-2148818
# 238 sub-2621689
# 240 sub-4371913
# 241 sub-1444628
# 242 sub-2945470
# 246 sub-4979032
# 249 sub-4895988
# 253 sub-1415090
# 256 sub-2604533
# 260 sub-1892858
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-c9957d08c0de> in <module>()
#      11
#      12         # get the array thanks to aims
# ---> 13         vol = aims.read(file_path)
#      14
#      15         arr = np.asarray(vol)
#
# /casa/host/build/python/soma/aims/__init__.py in read(filename, border, frame, dtype, allocmode, options, object)
#     556     r = Reader(allocmode=allocmode, options=options)
#     557     return r.read(filename, border=border, frame=frame, dtype=dtype,
# --> 558                   object=object)
#     559
#     560
#
# /casa/host/build/python/soma/aims/__init__.py in read(self, filename, border, frame, dtype, object)
#     381         '''
#     382         f = Finder()
# --> 383         if not f.check(filename):
#     384             open(filename).close()  # "file not found"-case raising first
#     385             raise IOError(
#
# KeyboardInterrupt:

# %%
#count_df.to_csv("./UKB_count_voxels.csv")
count_df = pd.read_csv("/neurospin/dico/data/deep_folding/current/datasets/UkBioBank/UKB_count_voxels.csv", index_col=0)
count_df
# Out:
#              count
# sub-2859308  14277
# sub-5201474  14333
# sub-2967866  14438
# sub-2707712  14502
# sub-4770610  14590
# sub-4897231  14609
# sub-2724047  14734
# sub-3387900  14736
# sub-2562798  14816
# sub-1082411  14825
# sub-1978043  14833
# sub-5711365  14844
# sub-1444628  14919
# sub-1340801  14940
# sub-1535763  14988
# sub-4542006  14994
# sub-2215815  15001
# sub-4606013  15019
# sub-4091566  15037
# sub-4372091  15064
# sub-3317995  15083
# sub-3143568  15093
# sub-1805227  15104
# sub-3473756  15116
# sub-1125717  15123
# sub-3050040  15137
# sub-5595581  15138
# sub-1052521  15140
# sub-4848955  15148
# sub-4314768  15148
# ...            ...
# sub-3490549  22032
# sub-5145267  22096
# sub-2146417  22349
# sub-2021210  22358
# sub-5472164  22537
# sub-3459925  22627
# sub-2481728  22685
# sub-5275233  22865
# sub-3396940  22921
# sub-2955962  22941
# sub-2718550  22978
# sub-5894417  23280
# sub-2809323  23440
# sub-1897786  24292
# sub-4517280  24436
# sub-2247652  24786
# sub-1195093  24839
# sub-4485612  24937
# sub-2100108  25529
# sub-4635239  25534
# sub-4220393  25651
# sub-1055585  25759
# sub-2241742  25847
# sub-5352915  27242
# sub-3107330  27373
# sub-2444304  29028
# sub-4497921  30180
# sub-2562650  31391
# sub-2354702  36342
# sub-5023037  39290
#
# [21072 rows x 1 columns]

# %%
plt.plot(count_df['count'])

# %%
quant = count_df['count'].quantile(q=0.9)

percent = 20
factor = 1+percent/100

print(quant, factor*quant)

exclude = count_df[count_df['count'] >= factor*quant]

print(exclude.shape[0])
exclude
# Out:
# 19328.0 23193.6
# 19
#              count
# sub-5894417  23280
# sub-2809323  23440
# sub-1897786  24292
# sub-4517280  24436
# sub-2247652  24786
# sub-1195093  24839
# sub-4485612  24937
# sub-2100108  25529
# sub-4635239  25534
# sub-4220393  25651
# sub-1055585  25759
# sub-2241742  25847
# sub-5352915  27242
# sub-3107330  27373
# sub-2444304  29028
# sub-4497921  30180
# sub-2562650  31391
# sub-2354702  36342
# sub-5023037  39290

# %%
exclude.to_csv("./bad_qc.csv")

# %%
count_df = count_df[~count_df.index.isin(exclude.index)]
count_df
# Out:
#              count
# sub-2859308  14277
# sub-5201474  14333
# sub-2967866  14438
# sub-2707712  14502
# sub-4770610  14590
# sub-4897231  14609
# sub-2724047  14734
# sub-3387900  14736
# sub-2562798  14816
# sub-1082411  14825
# ...            ...
# sub-5145267  22096
# sub-2146417  22349
# sub-2021210  22358
# sub-5472164  22537
# sub-3459925  22627
# sub-2481728  22685
# sub-5275233  22865
# sub-3396940  22921
# sub-2955962  22941
# sub-2718550  22978
#
# [21053 rows x 1 columns]

# %%
n_subjects = 1114

least_folded_sub = count_df.iloc[0:n_subjects,:].index
most_folded_sub = count_df.iloc[-n_subjects:,:].index

print(least_folded_sub)
print(most_folded_sub)
# Out:
# Index(['sub-2859308', 'sub-5201474', 'sub-2967866', 'sub-2707712',
#        'sub-4770610', 'sub-4897231', 'sub-2724047', 'sub-3387900',
#        'sub-2562798', 'sub-1082411',
#        ...
#        'sub-3882121', 'sub-2371387', 'sub-2697979', 'sub-4746824',
#        'sub-2426840', 'sub-5729360', 'sub-1160063', 'sub-2123483',
#        'sub-4794197', 'sub-1458379'],
#       dtype='object', length=1114)
# Index(['sub-4469507', 'sub-3784604', 'sub-1959785', 'sub-5531966',
#        'sub-5079960', 'sub-2917814', 'sub-4894505', 'sub-4714473',
#        'sub-6009541', 'sub-5519409',
#        ...
#        'sub-3396940', 'sub-2955962', 'sub-2718550', 'sub-5894417',
#        'sub-2809323', 'sub-1897786', 'sub-4517280', 'sub-2247652',
#        'sub-1195093', 'sub-4485612'],
#       dtype='object', length=1114)

# %%
least_folded_sub = pd.DataFrame(least_folded_sub, columns=['Subject'])
most_folded_sub = pd.DataFrame(most_folded_sub, columns=['Subject'])

# %%
least_folded_sub.to_csv("./least_folded_1114.csv", index=False)
most_folded_sub.to_csv("./most_folded_1114.csv", index=False)

# %% [markdown]
# ## Generate QC file UKB

# %%
save_path = "/neurospin/dico/data/deep_folding/current/datasets/UkBioBank"

missing_R_graphs = pd.read_csv(save_path+'/missing_R_graphs.csv', index_col=0, header=None)
too_many_voxels = pd.read_csv(save_path+'/too_many_voxels.csv', index_col=0)

# %%
# initializing

index = np.concatenate([count_df.index.values, missing_R_graphs.index.values])

qc_df = pd.DataFrame(columns=['qc', 'comments'], index=index)
qc_df = qc_df.assign(qc=1)
qc_df = qc_df.assign(comments='')

qc_df
# Out:
#              qc comments
# sub-2859308   1
# sub-5201474   1
# sub-2967866   1
# sub-2707712   1
# sub-4770610   1
# sub-4897231   1
# sub-2724047   1
# sub-3387900   1
# sub-2562798   1
# sub-1082411   1
# ...          ..      ...
# sub-3484445   1
# sub-1424513   1
# sub-5061299   1
# sub-4307046   1
# sub-1784389   1
# sub-4248122   1
# sub-5837347   1
# sub-4831006   1
# sub-4632380   1
# sub-2786702   1
#
# [21307 rows x 2 columns]

# %%
qc_df.loc[missing_R_graphs.index, 'qc'] = 0
qc_df.loc[missing_R_graphs.index, 'comments'] = 'missing R graph'

qc_df.loc[too_many_voxels.index, 'qc'] = 0
qc_df.loc[too_many_voxels.index, 'comments'] = 'too many voxels (more than 1.2 x 90th quantile)'

qc_df
# Out:
#              qc         comments
# sub-2859308   1
# sub-5201474   1
# sub-2967866   1
# sub-2707712   1
# sub-4770610   1
# sub-4897231   1
# sub-2724047   1
# sub-3387900   1
# sub-2562798   1
# sub-1082411   1
# ...          ..              ...
# sub-3484445   0  missing R graph
# sub-1424513   0  missing R graph
# sub-5061299   0  missing R graph
# sub-4307046   0  missing R graph
# sub-1784389   0  missing R graph
# sub-4248122   0  missing R graph
# sub-5837347   0  missing R graph
# sub-4831006   0  missing R graph
# sub-4632380   0  missing R graph
# sub-2786702   0  missing R graph
#
# [21307 rows x 2 columns]

# %%
qc_df.to_csv(save_path+'/qc.tsv', sep='\t')

# %% [markdown]
# ## Generate UKB subset

# %%
count_df = pd.read_csv("/neurospin/dico/data/deep_folding/current/datasets/UkBioBank/UKB_count_voxels.csv", index_col=0)
count_df
# Out:
#              count
# sub-2859308  14277
# sub-5201474  14333
# sub-2967866  14438
# sub-2707712  14502
# sub-4770610  14590
# ...            ...
# sub-2444304  29028
# sub-4497921  30180
# sub-2562650  31391
# sub-2354702  36342
# sub-5023037  39290
#
# [21072 rows x 1 columns]

# %%
milieu = int(count_df.shape[0]/2)
print(milieu)

size = 551

indices = range(int(milieu - size/2), int(milieu + size/2))
print((indices))
if len(indices) == size:
    subset_subjects = count_df.iloc[indices,:].index

subset_subjects
# Out:
# 10536
# range(10260, 10811)
# Index(['sub-5832389', 'sub-5786437', 'sub-4913005', 'sub-3619215',
#        'sub-3546706', 'sub-4581847', 'sub-5642476', 'sub-3767310',
#        'sub-4093965', 'sub-3679498',
#        ...
#        'sub-5380252', 'sub-4621986', 'sub-2854300', 'sub-2230015',
#        'sub-2827344', 'sub-1347343', 'sub-2598010', 'sub-2703169',
#        'sub-4878783', 'sub-1479908'],
#       dtype='object', length=551)

# %%
# save pandas file

subset_subjects_df = pd.DataFrame(subset_subjects, columns=['Subject'])
subset_subjects_df.to_csv("./mid_folded_551.csv", header=False, index=False)

# %% [markdown]
# # ACCpatterns

# %%
path2rescaled_skels = "/neurospin/dico/data/deep_folding/current/datasets/ACCpatterns/skeletons/2mm/R"

# %%
count_df = count_voxels(path2rescaled_skels)
# Out:
# 0 nih_chp_02657_t1
# 2 nih_chp_05537_t1
# 3 nih_chp_04276_t1
# 4 nih_chp_04807_t1
# 9 nih_chp_05627_t1
# 10 e0013_t1_s03
# 13 sub-active25_ses-pretraining_T1w
# 14 a0005_t1_s03
# 20 sub-inhibition16_ses-pretraining_T1w
# 22 nih_chp_02874_t1
# 23 nih_chp_04640_t1
# 24 nih_chp_03922_t1
# 28 nih_chp_05147_t1
# 29 nih_chp_01348_t1
# 30 nih_chp_05225_t1
# 31 e0061_t1_s03
# 32 nih_chp_01503_t1
# 33 e0032_t1_s03
# 34 nih_chp_05711_t1
# 37 nih_chp_05293_t1
# 38 nih_chp_04578_t1
# 40 2-14COEEN_t0
# 45 nih_chp_05167_t1
# 46 nih_chp_00404_t1
# 47 nih_chp_04911_t1
# 48 a0006_t1_s03
# 53 nih_chp_00551_t1
# 58 2-25MATMA_t0
# 59 a0009_t1_02_s03
# 60 nih_chp_05032_t1
# 61 e0067_t1_s03
# 62 a0038_t1_s03
# 63 a0002_t1_s03
# 66 nih_chp_04768_t1
# 67 nih_chp_05116_t1
# 71 1-08ANDTI_t0
# 73 nih_chp_01363_t1
# 74 nih_chp_05126_t1
# 75 nih_chp_01579_t1
# 80 nih_chp_05517_t1
# 82 a0034_t1_s03
# 85 nih_chp_02091_t1
# 87 e0070_t1_s03
# 89 nih_chp_04815_t1
# 90 1-11LEBJO_t0
# 93 nih_chp_05117_t1
# 94 nih_chp_02221_t1
# 97 sub-inhibition25_ses-pretraining_T1w
# 98 nih_chp_04808_t1
# 100 e0065_anat_t1_s03
# 103 nih_chp_01012_t1
# 105 a0017_t1_s03
# 106 a0025_t1_s03
# 107 nih_chp_04675_t1
# 108 nih_chp_01518_t1
# 109 nih_chp_04584_t1
# 112 nih_chp_05113_t1
# 114 nih_chp_01211_t1
# 117 nih_chp_02904_t1
# 118 e0041_t1_s03
# 121 e0082_t1_s03
# 122 2-18LELAM_t0
# 123 sub-inhibition02_ses-pretraining_T1w
# 125 nih_chp_01161_t1
# 126 nih_chp_04830_t1
# 131 nih_chp_02955_t1
# 135 nih_chp_05127_t1
# 136 nih_chp_05284_t1
# 137 nih_chp_04632_t1
# 138 a0024_t1_s03
# 140 nih_chp_03447_t1
# 141 e0073_t1_s03
# 143 a0037_t1_s03
# 146 sub-active14_ses-pretraining_T1w
# 147 nih_chp_04351_t1
# 155 nih_chp_03329_t1
# 156 a0027_t1_s03
# 158 e0077_t1_s03
# 159 nih_chp_01055_t1
# 160 nih_chp_04910_t1
# 161 a0033_t1_s03
# 164 nih_chp_04559_t1
# 166 nih_chp_04816_t1
# 170 nih_chp_02740_t1
# 171 nih_chp_02194_t1
# 173 1-17COLMA_t0
# 176 sub-inhibition05_ses-pretraining_T1w
# 180 sub-active09_ses-pretraining_T1w
# 181 sub-active11_ses-pretraining_T1w
# 182 sub-inhibition18_ses-pretraining_T1w
# 184 a0013_t1_s03
# 185 nih_chp_04220_t1
# 186 nih_chp_03404_t1
# 188 1-18ROUCO_t0
# 189 e0068_t1_s03
# 190 1-40AYMJU_t0
# 191 nih_chp_04701_t1
# 194 sub-active04_ses-pretraining_T1w
# 196 nih_chp_00872_t1
# 197 nih_chp_01052_t1
# 198 e0078_t1_s03
# 199 e0051_t1_s03
# 200 sub-inhibition26_ses-pretraining_T1w
# 201 nih_chp_05614_t1
# 202 nih_chp_04745_t1
# 207 nih_chp_05568_t1
# 211 a0029_t1_s03
# 212 nih_chp_05234_t1
# 216 nih_chp_01598_t1
# 217 nih_chp_05350_t1
# 218 2-11TREVA_t0
# 224 e0076_t1_s03
# 225 nih_chp_04572_t1
# 227 nih_chp_03373_t1
# 231 nih_chp_04579_t1
# 232 e0066_t1_s03
# 233 sub-active15_ses-pretraining_T1w
# 234 nih_chp_05752_t1
# 235 nih_chp_04809_t1
# 237 a0001_t1_s03
# 238 a0019_t1_s03
# 243 a0008_t1_s03
# 246 nih_chp_05041_t1
# 247 nih_chp_05069_t1
# 253 nih_chp_02373_t1
# 260 nih_chp_05567_t1
# 261 nih_chp_05652_t1
# 263 nih_chp_05376_t1
# 265 sub-inhibition29_ses-pretraining_T1w
# 268 e0079_t1_s03
# 269 nih_chp_05595_t1
# 271 a0030_t1_s03
# 273 1-23CREES_t0
# 274 nih_chp_00901_t1
# 275 nih_chp_02328_t1
# 279 nih_chp_02563_t1
# 281 nih_chp_04759_t1
# 289 sub-inhibition12_ses-pretraining_T1w
# 290 nih_chp_05070_t1
# 292 a0011_t1_s03
# 293 nih_chp_01044_t1
# 294 nih_chp_05312_t1
# 297 nih_chp_04766_t1
# 300 nih_chp_04569_t1
# 301 nih_chp_05226_t1
# 302 nih_chp_02488_t1
# 304 2-09MORJU_t0
# 305 sub-active08_ses-pretraining_T1w
# 306 nih_chp_01134_t1
# 307 nih_chp_04743_t1
# 308 nih_chp_00756_t1
# 309 nih_chp_04854_t1
# 312 nih_chp_04144_t1
# 313 a0028_t1_s03
# 314 nih_chp_03896_t1
# 315 sub-inhibition08_ses-pretraining_T1w
# 316 nih_chp_02949_t1
# 318 e0062_t1_s03
# 323 nih_chp_02991_t1
# 324 e0072_t1_s03
# 328 nih_chp_01487_t1
# 329 e0081_t1_s03
# 330 nih_chp_05136_t1
# 331 nih_chp_04778_t1
# 332 nih_chp_04580_t1
# 333 nih_chp_04623_t1
# 334 nih_chp_04767_t1
# 335 nih_chp_05777_t1
# 341 e0045_t1_s03
# 344 nih_chp_05235_t1
# 345 nih_chp_01604_t1
# 346 2-02FERMA_t0
# 348 nih_chp_03811_t1
# 349 e0049_t1_s03
# 350 nih_chp_04904_t1
# 351 a0004_t1_s03
# 354 sub-active18_ses-pretraining_T1w
# 355 nih_chp_03879_t1
# 357 nih_chp_03209_t1
# 358 nih_chp_04266_t1
# 360 a0020_t1_s03
# 361 nih_chp_04564_t1
# 363 1-15LEHMI_t0
# 364 e0053_t1_s03
# 366 nih_chp_04568_t1
# 367 nih_chp_05192_t1
# 370 sub-active10_ses-pretraining_T1w
# 371 sub-active02_ses-pretraining_T1w
# 372 e0083_t1_s03
# 373 nih_chp_01603_t1
# 374 a0007_t1_s03
# 376 nih_chp_05132_t1
# 377 nih_chp_04845_t1
# 379 sub-inhibition01_ses-pretraining_T1w
# 381 nih_chp_05651_t1
# 383 nih_chp_04132_t1
# 385 nih_chp_05429_t1
# 389 e0075_t1_s03
# 392 2-04HEBTO_t0
# 396 2-31LOEST_t0
# 399 e0063_t1_s03
# 400 nih_chp_02705_t1
# 403 nih_chp_04053_t1
# 405 sub-active13_ses-pretraining_T1w
# 407 e0080_t1_s03
# 408 sub-inhibition03_ses-pretraining_T1w
# 409 a0023_t1_s03
# 410 nih_chp_01417_t1
# 411 nih_chp_03502_t1
# 412 nih_chp_05066_t1
# 413 a0031_t1_s03
# 414 nih_chp_05505_t1
# 417 a0016_t1_s03
# 418 sub-active07_ses-pretraining_T1w
# 422 e0021_t1_s03
# 423 a0018_t1_s03
# 428 nih_chp_03777_t1
# 434 nih_chp_04667_t1
# 435 e0050_t1_s03
# 438 a0040_t1_s03
# 439 nih_chp_03908_t1
# 440 nih_chp_04438_t1
# 441 nih_chp_04145_t1
# 443 nih_chp_05662_t1
# 446 nih_chp_03963_t1
# 450 nih_chp_01149_t1
# 451 sub-inhibition20_ses-pretraining_T1w
# 453 2-29PIEMA_t0
# 454 nih_chp_04633_t1
# 455 a0014_t1_s03
# 457 e0042_t1_s03
# 458 nih_chp_04891_t1
# 459 sub-active26_ses-pretraining_T1w
# 461 e0035_t1_s03
# 462 nih_chp_01078_t1
# 468 nih_chp_05185_t1
# 469 sub-active12_ses-pretraining_T1w
# 470 sub-inhibition24_ses-pretraining_T1w
# 471 nih_chp_04282_t1
# 474 nih_chp_03458_t1
# 476 nih_chp_04680_t1
# 477 e0069_t1_s04
# 480 sub-inhibition04_ses-pretraining_T1w
# 482 nih_chp_05741_t1
# 483 1-03HUBJO_t0
# 484 e0039_t1_s03
# 487 nih_chp_05428_t1
# 488 nih_chp_04939_t1
# 494 sub-active01_ses-pretraining_T1w
# 495 nih_chp_04201_t1
# 499 a0022_t1_s03
# 501 nih_chp_05720_t1
# 504 nih_chp_03319_t1
# 505 sub-active05_ses-pretraining_T1w
# 506 nih_chp_02741_t1
# 507 sub-inhibition15_ses-pretraining_T1w
# 510 sub-inhibition17_ses-pretraining_T1w
# 511 nih_chp_00501_t1
# 512 a0032_t1_s03
# 515 sub-active17_ses-pretraining_T1w
# 516 a0026_t1_s03
# 518 2-08BESAG_t0
# 520 e0048_t1_s03
# 521 e0036_t1_s03
# 524 nih_chp_05687_t1
# 529 nih_chp_05344_t1
# 530 nih_chp_04452_t1
# 531 nih_chp_04888_t1
# 534 nih_chp_03202_t1
# 535 nih_chp_03881_t1
# 536 nih_chp_03812_t1
# 540 nih_chp_05503_t1
# 541 nih_chp_02195_t1
# 543 a0015_t1_s03
# 544 nih_chp_05430_t1
# 545 nih_chp_01534_t1
# 546 sub-inhibition14_ses-pretraining_T1w
# 547 nih_chp_03961_t1
# 548 sub-inhibition21_ses-pretraining_T1w
# 549 sub-inhibition31_ses-pretraining_T1w
# 551 nih_chp_05404_t1
# 554 e0059_t1_s03
# 555 nih_chp_01094_t1
# 559 nih_chp_05063_t1
# 560 nih_chp_03813_t1
# 567 nih_chp_00874_t1
# 571 e0064_anat_t1_s03
# 574 nih_chp_03858_t1
# 576 nih_chp_05008_t1
# 577 nih_chp_04571_t1
# 579 nih_chp_05362_t1
# 580 nih_chp_01967_t1
# 581 nih_chp_05190_t1
# 584 nih_chp_01746_t1
# 587 nih_chp_05261_t1
# 588 nih_chp_05068_t1
# 589 a0021_t1_s05
# 590 e0071_t1_s03
# 592 nih_chp_05625_t1
# 594 nih_chp_05600_t1
# 595 sub-inhibition07_ses-pretraining_T1w
# 596 nih_chp_02677_t1
# 597 a0003_t1_s03
# 598 e0058_t1_s03
# 600 1-20FORHU_t0
# 601 sub-active16_ses-pretraining_T1w
# 603 nih_chp_05330_t1
# 608 nih_chp_02993_t1
# 612 nih_chp_01226_t1
# 615 nih_chp_03880_t1
# 617 nih_chp_04338_t1
# 619 nih_chp_04581_t1
# 620 a0010_t1_s03
# 624 nih_chp_04657_t1
# 626 sub-inhibition23_ses-pretraining_T1w
# 627 a0039_t1_s03
# 628 nih_chp_03848_t1
# 631 nih_chp_05776_t1
# 632 nih_chp_05716_t1
# 633 nih_chp_01217_t1
# 636 sub-inhibition28_ses-pretraining_T1w
# 637 nih_chp_01911_t1
# 639 e0074_t1_s03
# 640 nih_chp_05013_t1
# 642 nih_chp_02769_t1
# 644 nih_chp_04195_t1
# 645 e0047_t1_s03
# 646 a0036_t1_s03
# 648 sub-inhibition10_ses-pretraining_T1w
# 651 sub-inhibition22_ses-pretraining_T1w
# 659 nih_chp_04118_t1
# 660 sub-active21_ses-pretraining_T1w
# 662 sub-active22_ses-pretraining_T1w
# 663 sub-active19_ses-pretraining_T1w
# 666 nih_chp_02307_t1
# 670 sub-active06_ses-pretraining_T1w
# 672 nih_chp_04591_t1
# 675 a0012_t1_s03
# 677 nih_chp_05243_t1
# 679 nih_chp_04963_t1
# 681 a0035_t1_s03

# %%
plt.plot(count_df['count'])
plt.show()

# %%
# load labels
acc_db = pd.read_csv("/neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-09-01/conv_T=0.5/cingulate_ACCpatterns_embeddings/cross_val_predicted_labels.csv")

labeled_subjects = acc_db[['Subject', 'label']]
labeled_subjects.set_index('Subject', inplace=True)

cmap = {0: 'blue', 1: 'red'}

labeled_subjects['color'] = labeled_subjects['label'].map(cmap)
labeled_subjects
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
#                                       label color
# Subject
# 1-03HUBJO_t0                              1   red
# 1-08ANDTI_t0                              1   red
# 1-11LEBJO_t0                              1   red
# 1-15LEHMI_t0                              0  blue
# 1-17COLMA_t0                              0  blue
# 1-18ROUCO_t0                              0  blue
# 1-20FORHU_t0                              0  blue
# 1-23CREES_t0                              0  blue
# 1-40AYMJU_t0                              1   red
# 2-02FERMA_t0                              0  blue
# ...                                     ...   ...
# sub-inhibition20_ses-pretraining_T1w      0  blue
# sub-inhibition21_ses-pretraining_T1w      1   red
# sub-inhibition22_ses-pretraining_T1w      1   red
# sub-inhibition23_ses-pretraining_T1w      0  blue
# sub-inhibition24_ses-pretraining_T1w      0  blue
# sub-inhibition25_ses-pretraining_T1w      1   red
# sub-inhibition26_ses-pretraining_T1w      0  blue
# sub-inhibition28_ses-pretraining_T1w      0  blue
# sub-inhibition29_ses-pretraining_T1w      0  blue
# sub-inhibition31_ses-pretraining_T1w      0  blue
#
# [341 rows x 2 columns]

# %%
count_df['label'] = labeled_subjects.label
count_df['color'] = labeled_subjects['color']
count_df
# Out:
#                                       count  label color
# nih_chp_01211_t1                      10838      0  blue
# nih_chp_02373_t1                      11455      0  blue
# nih_chp_05185_t1                      11970      0  blue
# nih_chp_05041_t1                      12061      1   red
# nih_chp_03880_t1                      12750      1   red
# nih_chp_04579_t1                      12808      1   red
# nih_chp_05167_t1                      12809      1   red
# nih_chp_03922_t1                      12937      1   red
# nih_chp_04963_t1                      12938      0  blue
# nih_chp_05116_t1                      13071      0  blue
# ...                                     ...    ...   ...
# e0062_t1_s03                          19878      0  blue
# sub-active16_ses-pretraining_T1w      19919      1   red
# e0047_t1_s03                          20195      0  blue
# e0082_t1_s03                          20288      1   red
# e0075_t1_s03                          20345      0  blue
# sub-inhibition22_ses-pretraining_T1w  20368      1   red
# nih_chp_04438_t1                      20554      0  blue
# sub-inhibition01_ses-pretraining_T1w  20631      1   red
# e0061_t1_s03                          20684      1   red
# e0059_t1_s03                          21244      1   red
#
# [341 rows x 3 columns]

# %%
plt.figure(figsize=(12,8))
plt.bar(range(count_df.shape[0]), count_df['count'], color=count_df.color)
# Out:
# <BarContainer object of 341 artists>

# %%
bins = range(10500, 22000, 500)

no_pcgs = count_df[count_df.color=='blue']['count']
pcgs = count_df[count_df.color=='red']['count']

print("No paracingulate sulcus:", no_pcgs.mean(), "+/-", no_pcgs.std())
print("Paracingulate sulcus:", pcgs.mean(), "+/-",pcgs.std())

plt.hist(no_pcgs, bins=bins, color='blue', alpha=0.5)
plt.hist(pcgs, bins=bins, color='red', alpha=0.5)
plt.xlabel("nb voxels (full hemisphere)")

mean = count_df['count'].mean()
xmin, xmax, ymin, ymax = plt.axis()
plt.vlines(mean, ymin, ymax, colors='black')
#plt.vlines(no_pcgs.mean(), ymin, ymax, colors='blue', alpha=0.8)
#plt.vlines(pcgs.mean(), ymin, ymax, colors='red',  alpha=0.8)

plt.show()
# Out:
# No paracingulate sulcus: 16281.274111675128 +/- 1766.622632743126
# Paracingulate sulcus: 16439.180555555555 +/- 1876.7372731276328

# %%
# naive predictor

mean = count_df['count'].mean()
count_df['naive_prediction'] = (count_df['count'] > mean).astype(int)

naive_accuracy = (count_df.label == count_df.naive_prediction).mean()
naive_accuracy
# Out:
# 0.501466275659824

# %% [markdown]
# ## count on crop

# %%
path2crops = "/neurospin/dico/data/deep_folding/current/datasets/ACCpatterns/crops/2mm/CINGULATE/mask/Rcrops"

# %%
count_df = count_voxels(path2crops, dtype='crop')
count_df
# Out:
# 2 sub-inhibition28_ses-pretraining_T1w
# 3 sub-active18_ses-pretraining_T1w
# 4 nih_chp_00404_t1
# 5 nih_chp_03961_t1
# 6 nih_chp_05069_t1
# 7 e0042_t1_s03
# 8 sub-active08_ses-pretraining_T1w
# 10 a0034_t1_s03
# 11 e0021_t1_s03
# 12 a0040_t1_s03
# 13 nih_chp_03202_t1
# 14 nih_chp_04195_t1
# 16 nih_chp_04438_t1
# 17 nih_chp_04854_t1
# 21 nih_chp_05344_t1
# 24 nih_chp_04910_t1
# 26 nih_chp_03908_t1
# 27 nih_chp_01055_t1
# 33 nih_chp_05116_t1
# 34 nih_chp_05517_t1
# 40 nih_chp_05716_t1
# 42 nih_chp_02741_t1
# 47 a0004_t1_s03
# 48 nih_chp_01078_t1
# 49 nih_chp_04053_t1
# 50 nih_chp_05293_t1
# 52 a0026_t1_s03
# 53 nih_chp_04808_t1
# 54 sub-active15_ses-pretraining_T1w
# 55 1-18ROUCO_t0
# 57 nih_chp_02221_t1
# 58 a0036_t1_s03
# 59 a0018_t1_s03
# 60 nih_chp_05066_t1
# 63 nih_chp_01052_t1
# 64 nih_chp_04701_t1
# 67 nih_chp_04338_t1
# 68 sub-active02_ses-pretraining_T1w
# 70 nih_chp_04144_t1
# 71 nih_chp_05404_t1
# 73 a0010_t1_s03
# 75 nih_chp_01967_t1
# 77 nih_chp_04667_t1
# 78 nih_chp_05127_t1
# 80 2-29PIEMA_t0
# 81 1-11LEBJO_t0
# 82 nih_chp_01911_t1
# 83 nih_chp_02769_t1
# 84 e0039_t1_s03
# 87 nih_chp_01211_t1
# 88 a0009_t1_02_s03
# 90 nih_chp_04767_t1
# 91 nih_chp_02091_t1
# 93 nih_chp_04745_t1
# 96 nih_chp_03858_t1
# 101 nih_chp_05063_t1
# 105 2-09MORJU_t0
# 106 e0073_t1_s03
# 109 nih_chp_02949_t1
# 110 nih_chp_01503_t1
# 111 nih_chp_05505_t1
# 112 sub-active04_ses-pretraining_T1w
# 116 nih_chp_01149_t1
# 119 nih_chp_05651_t1
# 120 nih_chp_03879_t1
# 125 sub-active01_ses-pretraining_T1w
# 129 a0037_t1_s03
# 130 a0021_t1_s05
# 133 a0028_t1_s03
# 134 sub-inhibition07_ses-pretraining_T1w
# 135 nih_chp_04623_t1
# 139 nih_chp_04911_t1
# 143 e0045_t1_s03
# 147 e0079_t1_s03
# 148 nih_chp_04580_t1
# 150 e0053_t1_s03
# 158 a0025_t1_s03
# 160 nih_chp_03458_t1
# 161 a0001_t1_s03
# 162 nih_chp_03880_t1
# 164 nih_chp_02195_t1
# 166 nih_chp_02488_t1
# 167 1-08ANDTI_t0
# 168 nih_chp_04282_t1
# 169 nih_chp_04220_t1
# 171 e0068_t1_s03
# 172 nih_chp_04266_t1
# 174 e0061_t1_s03
# 176 nih_chp_01217_t1
# 178 nih_chp_05627_t1
# 180 nih_chp_02740_t1
# 185 a0019_t1_s03
# 187 nih_chp_03447_t1
# 189 sub-inhibition04_ses-pretraining_T1w
# 192 nih_chp_02705_t1
# 195 sub-inhibition24_ses-pretraining_T1w
# 201 sub-inhibition29_ses-pretraining_T1w
# 202 nih_chp_05113_t1
# 203 nih_chp_04145_t1
# 205 nih_chp_01363_t1
# 208 nih_chp_01161_t1
# 209 nih_chp_03813_t1
# 211 nih_chp_04632_t1
# 213 nih_chp_05190_t1
# 214 nih_chp_05243_t1
# 215 sub-inhibition14_ses-pretraining_T1w
# 218 nih_chp_02373_t1
# 219 nih_chp_05284_t1
# 220 e0059_t1_s03
# 222 2-31LOEST_t0
# 224 nih_chp_05662_t1
# 228 nih_chp_04743_t1
# 229 a0015_t1_s03
# 231 sub-active09_ses-pretraining_T1w
# 232 nih_chp_03404_t1
# 233 nih_chp_02955_t1
# 235 nih_chp_05652_t1
# 237 sub-active12_ses-pretraining_T1w
# 238 nih_chp_02307_t1
# 240 nih_chp_04845_t1
# 242 nih_chp_05776_t1
# 243 e0075_t1_s03
# 244 nih_chp_05330_t1
# 245 e0071_t1_s03
# 246 a0002_t1_s03
# 247 sub-active26_ses-pretraining_T1w
# 248 2-02FERMA_t0
# 252 nih_chp_02657_t1
# 253 a0039_t1_s03
# 254 sub-inhibition15_ses-pretraining_T1w
# 255 a0027_t1_s03
# 257 a0017_t1_s03
# 262 nih_chp_04778_t1
# 263 sub-inhibition20_ses-pretraining_T1w
# 265 a0035_t1_s03
# 267 nih_chp_04452_t1
# 268 nih_chp_01598_t1
# 272 a0031_t1_s03
# 273 nih_chp_04276_t1
# 276 nih_chp_04809_t1
# 277 nih_chp_05167_t1
# 278 nih_chp_05350_t1
# 279 e0051_t1_s03
# 280 a0033_t1_s03
# 283 nih_chp_03848_t1
# 285 nih_chp_03812_t1
# 288 sub-inhibition16_ses-pretraining_T1w
# 292 nih_chp_01226_t1
# 293 nih_chp_05362_t1
# 294 nih_chp_01534_t1
# 296 nih_chp_04568_t1
# 297 nih_chp_04132_t1
# 300 a0022_t1_s03
# 304 nih_chp_03502_t1
# 305 e0065_anat_t1_s03
# 306 sub-active19_ses-pretraining_T1w
# 307 nih_chp_04891_t1
# 308 2-04HEBTO_t0
# 309 nih_chp_05013_t1
# 310 2-25MATMA_t0
# 314 nih_chp_04584_t1
# 315 e0078_t1_s03
# 318 nih_chp_04572_t1
# 319 e0032_t1_s03
# 322 nih_chp_05687_t1
# 323 2-11TREVA_t0
# 327 sub-active22_ses-pretraining_T1w
# 328 e0083_t1_s03
# 329 nih_chp_05312_t1
# 332 e0013_t1_s03
# 333 sub-inhibition17_ses-pretraining_T1w
# 339 nih_chp_02991_t1
# 340 2-14COEEN_t0
# 341 nih_chp_05032_t1
# 344 nih_chp_01518_t1
# 348 e0072_t1_s03
# 351 e0062_t1_s03
# 352 e0048_t1_s03
# 353 nih_chp_03777_t1
# 354 e0047_t1_s03
# 356 e0064_anat_t1_s03
# 357 nih_chp_04904_t1
# 359 nih_chp_05192_t1
# 363 a0011_t1_s03
# 364 e0035_t1_s03
# 365 2-08BESAG_t0
# 366 nih_chp_05567_t1
# 367 nih_chp_03963_t1
# 369 e0076_t1_s03
# 374 nih_chp_04939_t1
# 376 nih_chp_01746_t1
# 377 nih_chp_04633_t1
# 380 nih_chp_02904_t1
# 381 nih_chp_04816_t1
# 384 nih_chp_05600_t1
# 385 nih_chp_01603_t1
# 387 nih_chp_01417_t1
# 388 nih_chp_04571_t1
# 389 nih_chp_01604_t1
# 390 nih_chp_05132_t1
# 398 nih_chp_05070_t1
# 407 nih_chp_04768_t1
# 408 nih_chp_04351_t1
# 410 nih_chp_04578_t1
# 411 nih_chp_04591_t1
# 413 nih_chp_05537_t1
# 415 e0049_t1_s03
# 416 a0023_t1_s03
# 417 nih_chp_04963_t1
# 418 nih_chp_05568_t1
# 421 nih_chp_04118_t1
# 424 a0016_t1_s03
# 427 nih_chp_01012_t1
# 430 sub-active11_ses-pretraining_T1w
# 433 sub-inhibition10_ses-pretraining_T1w
# 436 nih_chp_04657_t1
# 438 nih_chp_02677_t1
# 439 nih_chp_01134_t1
# 440 nih_chp_05261_t1
# 441 1-40AYMJU_t0
# 444 e0063_t1_s03
# 445 nih_chp_05376_t1
# 447 nih_chp_05429_t1
# 452 sub-inhibition02_ses-pretraining_T1w
# 456 nih_chp_03329_t1
# 457 nih_chp_05752_t1
# 459 nih_chp_00756_t1
# 461 sub-inhibition23_ses-pretraining_T1w
# 462 sub-inhibition26_ses-pretraining_T1w
# 464 a0013_t1_s03
# 465 nih_chp_05720_t1
# 467 nih_chp_05595_t1
# 469 a0003_t1_s03
# 471 sub-inhibition18_ses-pretraining_T1w
# 474 nih_chp_02993_t1
# 475 sub-inhibition12_ses-pretraining_T1w
# 477 nih_chp_03922_t1
# 482 sub-active17_ses-pretraining_T1w
# 486 nih_chp_04564_t1
# 487 sub-inhibition31_ses-pretraining_T1w
# 492 nih_chp_04581_t1
# 493 nih_chp_04559_t1
# 494 1-17COLMA_t0
# 496 sub-inhibition22_ses-pretraining_T1w
# 497 nih_chp_05226_t1
# 498 nih_chp_04759_t1
# 501 nih_chp_05041_t1
# 503 1-03HUBJO_t0
# 506 nih_chp_05741_t1
# 507 sub-inhibition21_ses-pretraining_T1w
# 509 e0080_t1_s03
# 510 nih_chp_04675_t1
# 511 a0020_t1_s03
# 512 e0070_t1_s03
# 516 nih_chp_02328_t1
# 522 e0041_t1_s03
# 523 a0038_t1_s03
# 524 nih_chp_03881_t1
# 527 nih_chp_01044_t1
# 529 nih_chp_05136_t1
# 531 e0050_t1_s03
# 533 sub-inhibition03_ses-pretraining_T1w
# 534 e0077_t1_s03
# 535 nih_chp_05147_t1
# 537 nih_chp_05225_t1
# 541 nih_chp_04815_t1
# 543 nih_chp_04830_t1
# 545 nih_chp_05235_t1
# 549 nih_chp_05614_t1
# 552 e0058_t1_s03
# 554 nih_chp_00872_t1
# 555 a0024_t1_s03
# 558 nih_chp_02563_t1
# 560 sub-active05_ses-pretraining_T1w
# 562 nih_chp_01348_t1
# 563 e0082_t1_s03
# 564 a0029_t1_s03
# 567 sub-active13_ses-pretraining_T1w
# 569 a0012_t1_s03
# 570 nih_chp_05185_t1
# 571 nih_chp_05117_t1
# 573 nih_chp_04888_t1
# 574 nih_chp_05625_t1
# 575 nih_chp_04201_t1
# 582 1-15LEHMI_t0
# 584 nih_chp_03811_t1
# 586 a0014_t1_s03
# 589 e0081_t1_s03
# 591 nih_chp_05430_t1
# 594 nih_chp_03373_t1
# 595 nih_chp_03209_t1
# 597 nih_chp_05068_t1
# 599 nih_chp_00551_t1
# 600 nih_chp_03319_t1
# 602 sub-active07_ses-pretraining_T1w
# 603 a0032_t1_s03
# 605 e0069_t1_s04
# 606 sub-active16_ses-pretraining_T1w
# 607 sub-inhibition08_ses-pretraining_T1w
# 608 nih_chp_05777_t1
# 609 nih_chp_04569_t1
# 612 sub-inhibition01_ses-pretraining_T1w
# 615 nih_chp_05428_t1
# 616 nih_chp_00901_t1
# 619 a0008_t1_s03
# 620 nih_chp_03896_t1
# 621 nih_chp_04579_t1
# 622 sub-active10_ses-pretraining_T1w
# 623 a0006_t1_s03
# 625 a0005_t1_s03
# 627 nih_chp_04807_t1
# 629 nih_chp_05008_t1
# 630 e0066_t1_s03
# 632 sub-active21_ses-pretraining_T1w
# 633 1-23CREES_t0
# 634 a0007_t1_s03
# 636 nih_chp_04680_t1
# 637 nih_chp_05126_t1
# 639 nih_chp_05503_t1
# 641 nih_chp_05234_t1
# 642 1-20FORHU_t0
# 643 e0036_t1_s03
# 647 nih_chp_02194_t1
# 649 nih_chp_02874_t1
# 650 sub-active25_ses-pretraining_T1w
# 656 nih_chp_01094_t1
# 657 e0067_t1_s03
# 663 nih_chp_00874_t1
# 664 sub-inhibition25_ses-pretraining_T1w
# 665 e0074_t1_s03
# 666 a0030_t1_s03
# 668 nih_chp_04766_t1
# 669 sub-active14_ses-pretraining_T1w
# 671 sub-inhibition05_ses-pretraining_T1w
# 673 sub-active06_ses-pretraining_T1w
# 675 nih_chp_05711_t1
# 676 2-18LELAM_t0
# 677 nih_chp_01579_t1
# 679 nih_chp_01487_t1
# 680 nih_chp_04640_t1
# 681 nih_chp_00501_t1
#                                       count
# sub-active08_ses-pretraining_T1w        341
# nih_chp_03880_t1                        384
# sub-inhibition28_ses-pretraining_T1w    424
# nih_chp_01211_t1                        429
# sub-active19_ses-pretraining_T1w        553
# nih_chp_02373_t1                        558
# nih_chp_04579_t1                        564
# sub-inhibition01_ses-pretraining_T1w    577
# nih_chp_05167_t1                        577
# nih_chp_05625_t1                        579
# ...                                     ...
# nih_chp_05190_t1                        956
# nih_chp_02993_t1                        957
# nih_chp_04438_t1                        960
# 2-04HEBTO_t0                            962
# e0039_t1_s03                            966
# e0021_t1_s03                            980
# e0082_t1_s03                            984
# nih_chp_05362_t1                        997
# e0053_t1_s03                           1027
# e0058_t1_s03                           1099
#
# [341 rows x 1 columns]

# %%
plt.plot(count_df['count'])
plt.show()

# %%
# load labels
acc_db = pd.read_csv("/neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-09-01/conv_T=0.5/cingulate_ACCpatterns_embeddings/cross_val_predicted_labels.csv")

labeled_subjects = acc_db[['Subject', 'label']]
labeled_subjects.set_index('Subject', inplace=True)

cmap = {0: 'blue', 1: 'red'}

labeled_subjects['color'] = labeled_subjects['label'].map(cmap)
labeled_subjects
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
#                                       label color
# Subject
# 1-03HUBJO_t0                              1   red
# 1-08ANDTI_t0                              1   red
# 1-11LEBJO_t0                              1   red
# 1-15LEHMI_t0                              0  blue
# 1-17COLMA_t0                              0  blue
# 1-18ROUCO_t0                              0  blue
# 1-20FORHU_t0                              0  blue
# 1-23CREES_t0                              0  blue
# 1-40AYMJU_t0                              1   red
# 2-02FERMA_t0                              0  blue
# ...                                     ...   ...
# sub-inhibition20_ses-pretraining_T1w      0  blue
# sub-inhibition21_ses-pretraining_T1w      1   red
# sub-inhibition22_ses-pretraining_T1w      1   red
# sub-inhibition23_ses-pretraining_T1w      0  blue
# sub-inhibition24_ses-pretraining_T1w      0  blue
# sub-inhibition25_ses-pretraining_T1w      1   red
# sub-inhibition26_ses-pretraining_T1w      0  blue
# sub-inhibition28_ses-pretraining_T1w      0  blue
# sub-inhibition29_ses-pretraining_T1w      0  blue
# sub-inhibition31_ses-pretraining_T1w      0  blue
#
# [341 rows x 2 columns]

# %%
count_df['label'] = labeled_subjects.label
count_df['color'] = labeled_subjects['color']
count_df
# Out:
#                                       count  label color
# sub-active08_ses-pretraining_T1w        341      1   red
# nih_chp_03880_t1                        384      1   red
# sub-inhibition28_ses-pretraining_T1w    424      0  blue
# nih_chp_01211_t1                        429      0  blue
# sub-active19_ses-pretraining_T1w        553      0  blue
# nih_chp_02373_t1                        558      0  blue
# nih_chp_04579_t1                        564      1   red
# sub-inhibition01_ses-pretraining_T1w    577      1   red
# nih_chp_05167_t1                        577      1   red
# nih_chp_05625_t1                        579      1   red
# ...                                     ...    ...   ...
# nih_chp_05190_t1                        956      0  blue
# nih_chp_02993_t1                        957      1   red
# nih_chp_04438_t1                        960      0  blue
# 2-04HEBTO_t0                            962      1   red
# e0039_t1_s03                            966      0  blue
# e0021_t1_s03                            980      1   red
# e0082_t1_s03                            984      1   red
# nih_chp_05362_t1                        997      1   red
# e0053_t1_s03                           1027      1   red
# e0058_t1_s03                           1099      1   red
#
# [341 rows x 3 columns]

# %%
plt.figure(figsize=(12,8))
plt.bar(range(count_df.shape[0]), count_df['count'], color=count_df.color)
plt.show()

# %%
bins = range(300, 1150, 50)

no_pcgs = count_df[count_df.color=='blue']['count']
pcgs = count_df[count_df.color=='red']['count']

print("No paracingulate sulcus:", no_pcgs.mean(), "+/-", no_pcgs.std())
print("Paracingulate sulcus:", pcgs.mean(), "+/-",pcgs.std())

plt.hist(no_pcgs, bins=bins, color='blue', alpha=0.5)
plt.hist(pcgs, bins=bins, color='red', alpha=0.5)
plt.xlabel("nb voxels (cingulate crop)")

mean = count_df['count'].mean()
xmin, xmax, ymin, ymax = plt.axis()
plt.vlines(mean, ymin, ymax, colors='black')
#plt.vlines(no_pcgs.mean(), ymin, ymax, colors='blue', alpha=0.8)
#plt.vlines(pcgs.mean(), ymin, ymax, colors='red',  alpha=0.8)

plt.show()
# Out:
# No paracingulate sulcus: 747.2335025380711 +/- 89.5966374552186
# Paracingulate sulcus: 773.625 +/- 108.69279702847896

# %%
# naive predictor

mean = count_df['count'].mean()
count_df['naive_prediction'] = (count_df['count'] > mean).astype(int)

naive_accuracy = (count_df.label == count_df.naive_prediction).mean()
naive_accuracy
# Out:
# 0.5689149560117303
