# %%
import pandas as pd
import matplotlib.pyplot as plt
from umap import UMAP
import numpy as np

# %%
info = pd.read_csv("/neurospin/dico/data/bv_databases/human/partially_labeled/ACCpatterns/all.csv",index_col=0)
info = info[~info.long_name.isna()]
info = info.sort_values(by="long_name", ignore_index=True)
info
# Out:
#      PERSON_ID Sujet          name DATABASE  SEX HAND IRM_NAME0 IRM_NAME1  \
# 0          NaN   NaN       03HUBJO     APEX  NaN  NaN       NaN       NaN
# 1          NaN   NaN       08ANDTI     APEX  NaN  NaN       NaN       NaN
# 2          NaN   NaN       11LEBJO     APEX  NaN  NaN       NaN       NaN
# 3          NaN   NaN       15LEHMI     APEX  NaN  NaN       NaN       NaN
# 4          NaN   NaN       17COLMA     APEX  NaN  NaN       NaN       NaN
# ..         ...   ...           ...      ...  ...  ...       ...       ...
# 336        NaN   NaN  inhibition25     APEX  NaN  NaN       NaN       NaN
# 337        NaN   NaN  inhibition26     APEX  NaN  NaN       NaN       NaN
# 338        NaN   NaN  inhibition28     APEX  NaN  NaN       NaN       NaN
# 339        NaN   NaN  inhibition29     APEX  NaN  NaN       NaN       NaN
# 340        NaN   NaN  inhibition31     APEX  NaN  NaN       NaN       NaN
#
#                                 long_name Left_PCS  ... Inc-coul TMTA TMTB  \
# 0                            1-03HUBJO_t0   absent  ...      NaN  NaN  NaN
# 1                            1-08ANDTI_t0  present  ...      NaN  NaN  NaN
# 2                            1-11LEBJO_t0  present  ...      NaN  NaN  NaN
# 3                            1-15LEHMI_t0  present  ...      NaN  NaN  NaN
# 4                            1-17COLMA_t0  present  ...      NaN  NaN  NaN
# ..                                    ...      ...  ...      ...  ...  ...
# 336  sub-inhibition25_ses-pretraining_T1w  present  ...      NaN  NaN  NaN
# 337  sub-inhibition26_ses-pretraining_T1w   absent  ...      NaN  NaN  NaN
# 338  sub-inhibition28_ses-pretraining_T1w   absent  ...      NaN  NaN  NaN
# 339  sub-inhibition29_ses-pretraining_T1w   absent  ...      NaN  NaN  NaN
# 340  sub-inhibition31_ses-pretraining_T1w   absent  ...      NaN  NaN  NaN
#
#      Flex right_3level left_2level right_2level Asym3_from2 Asym3_from3  \
# 0     NaN          NaN         NaN          NaN         NaN         NaN
# 1     NaN          NaN         NaN          NaN         NaN         NaN
# 2     NaN          NaN         NaN          NaN         NaN         NaN
# 3     NaN          NaN         NaN          NaN         NaN         NaN
# 4     NaN          NaN         NaN          NaN         NaN         NaN
# ..    ...          ...         ...          ...         ...         ...
# 336   NaN          NaN         NaN          NaN         NaN         NaN
# 337   NaN          NaN         NaN          NaN         NaN         NaN
# 338   NaN          NaN         NaN          NaN         NaN         NaN
# 339   NaN          NaN         NaN          NaN         NaN         NaN
# 340   NaN          NaN         NaN          NaN         NaN         NaN
#
#     Asym2_from2
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ..          ...
# 336         NaN
# 337         NaN
# 338         NaN
# 339         NaN
# 340         NaN
#
# [341 rows x 63 columns]

# %%
info.DATABASE
# Out:
# 249    APEX
# 252    APEX
# 254    APEX
# 257    APEX
# 259    APEX
#        ...
# 241    APEX
# 244    APEX
# 246    APEX
# 247    APEX
# 237    APEX
# Name: DATABASE, Length: 341, dtype: object

# %%
apex = info[info.DATABASE == 'APEX']
nimh = info[info.DATABASE.str.contains('NIMH')]
tissier = info[info.DATABASE.str.contains('TISSIER')]

base_dico = {"APEX": 'red', 'NIMH_COS': 'green', 'NIMH_NV': 'green', 'NIMH_COSSIB': 'green', 'TISSIER_2018': 'blue'}

apex
# Out:
#      PERSON_ID Sujet          name DATABASE  SEX HAND IRM_NAME0 IRM_NAME1  \
# 0          NaN   NaN       03HUBJO     APEX  NaN  NaN       NaN       NaN
# 1          NaN   NaN       08ANDTI     APEX  NaN  NaN       NaN       NaN
# 2          NaN   NaN       11LEBJO     APEX  NaN  NaN       NaN       NaN
# 3          NaN   NaN       15LEHMI     APEX  NaN  NaN       NaN       NaN
# 4          NaN   NaN       17COLMA     APEX  NaN  NaN       NaN       NaN
# ..         ...   ...           ...      ...  ...  ...       ...       ...
# 336        NaN   NaN  inhibition25     APEX  NaN  NaN       NaN       NaN
# 337        NaN   NaN  inhibition26     APEX  NaN  NaN       NaN       NaN
# 338        NaN   NaN  inhibition28     APEX  NaN  NaN       NaN       NaN
# 339        NaN   NaN  inhibition29     APEX  NaN  NaN       NaN       NaN
# 340        NaN   NaN  inhibition31     APEX  NaN  NaN       NaN       NaN
#
#                                 long_name Left_PCS  ... Inc-coul TMTA TMTB  \
# 0                            1-03HUBJO_t0   absent  ...      NaN  NaN  NaN
# 1                            1-08ANDTI_t0  present  ...      NaN  NaN  NaN
# 2                            1-11LEBJO_t0  present  ...      NaN  NaN  NaN
# 3                            1-15LEHMI_t0  present  ...      NaN  NaN  NaN
# 4                            1-17COLMA_t0  present  ...      NaN  NaN  NaN
# ..                                    ...      ...  ...      ...  ...  ...
# 336  sub-inhibition25_ses-pretraining_T1w  present  ...      NaN  NaN  NaN
# 337  sub-inhibition26_ses-pretraining_T1w   absent  ...      NaN  NaN  NaN
# 338  sub-inhibition28_ses-pretraining_T1w   absent  ...      NaN  NaN  NaN
# 339  sub-inhibition29_ses-pretraining_T1w   absent  ...      NaN  NaN  NaN
# 340  sub-inhibition31_ses-pretraining_T1w   absent  ...      NaN  NaN  NaN
#
#      Flex right_3level left_2level right_2level Asym3_from2 Asym3_from3  \
# 0     NaN          NaN         NaN          NaN         NaN         NaN
# 1     NaN          NaN         NaN          NaN         NaN         NaN
# 2     NaN          NaN         NaN          NaN         NaN         NaN
# 3     NaN          NaN         NaN          NaN         NaN         NaN
# 4     NaN          NaN         NaN          NaN         NaN         NaN
# ..    ...          ...         ...          ...         ...         ...
# 336   NaN          NaN         NaN          NaN         NaN         NaN
# 337   NaN          NaN         NaN          NaN         NaN         NaN
# 338   NaN          NaN         NaN          NaN         NaN         NaN
# 339   NaN          NaN         NaN          NaN         NaN         NaN
# 340   NaN          NaN         NaN          NaN         NaN         NaN
#
#     Asym2_from2
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ..          ...
# 336         NaN
# 337         NaN
# 338         NaN
# 339         NaN
# 340         NaN
#
# [65 rows x 63 columns]

# %%
# get subjects with proeminent right PCGS
proems = info[info.right_3level == 'proeminent'].long_name
proems
# Out:
# 19    a0001_t1_s03
# 57    a0039_t1_s03
# 60    e0021_t1_s03
# 63    e0036_t1_s03
# 67    e0045_t1_s03
# 72    e0051_t1_s03
# 73    e0053_t1_s03
# 75    e0059_t1_s03
# 84    e0069_t1_s04
# 86    e0071_t1_s03
# 87    e0072_t1_s03
# 97    e0082_t1_s03
# Name: long_name, dtype: object

# %%
embs = pd.read_csv('/neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-09-30/17-27-31/cingulate_ACCpatterns_embeddings/full_embeddings.csv')
embs = embs.sort_values(by='ID', ignore_index=True)
embs
# Out:
#                                        ID       dim1       dim2       dim3  \
# 0                            1-03HUBJO_t0  13.746984   6.940231  -8.988678
# 1                            1-08ANDTI_t0  10.039248   3.071566 -23.064545
# 2                            1-11LEBJO_t0  15.008720   1.371084 -23.351560
# 3                            1-15LEHMI_t0  14.159241   4.401712 -15.933049
# 4                            1-17COLMA_t0   4.259211  15.044788 -10.106764
# ..                                    ...        ...        ...        ...
# 336  sub-inhibition25_ses-pretraining_T1w   6.381626  -4.734384   0.285639
# 337  sub-inhibition26_ses-pretraining_T1w  -1.740220  -4.981936  -3.523232
# 338  sub-inhibition28_ses-pretraining_T1w   2.437700   5.695477  -7.293016
# 339  sub-inhibition29_ses-pretraining_T1w  -2.627184   1.975519 -14.586481
# 340  sub-inhibition31_ses-pretraining_T1w  -0.388288   9.877884 -13.589944
#
#           dim4
# 0    -0.654266
# 1    -7.683618
# 2    -6.521302
# 3   -19.087380
# 4   -20.030579
# ..         ...
# 336 -12.346708
# 337 -13.342991
# 338  -4.273985
# 339 -10.016541
# 340  -2.042444
#
# [341 rows x 5 columns]

# %%
embs['source'] = info.DATABASE
embs['PCGS'] = info.Right_PCS
embs.loc[info.right_3level == 'proeminent', 'PCGS'] = 'proeminent'

embs
# Out:
#                                        ID       dim1       dim2       dim3  \
# 0                            1-03HUBJO_t0  13.746984   6.940231  -8.988678
# 1                            1-08ANDTI_t0  10.039248   3.071566 -23.064545
# 2                            1-11LEBJO_t0  15.008720   1.371084 -23.351560
# 3                            1-15LEHMI_t0  14.159241   4.401712 -15.933049
# 4                            1-17COLMA_t0   4.259211  15.044788 -10.106764
# ..                                    ...        ...        ...        ...
# 336  sub-inhibition25_ses-pretraining_T1w   6.381626  -4.734384   0.285639
# 337  sub-inhibition26_ses-pretraining_T1w  -1.740220  -4.981936  -3.523232
# 338  sub-inhibition28_ses-pretraining_T1w   2.437700   5.695477  -7.293016
# 339  sub-inhibition29_ses-pretraining_T1w  -2.627184   1.975519 -14.586481
# 340  sub-inhibition31_ses-pretraining_T1w  -0.388288   9.877884 -13.589944
#
#           dim4 source     PCGS
# 0    -0.654266   APEX  present
# 1    -7.683618   APEX  present
# 2    -6.521302   APEX  present
# 3   -19.087380   APEX   absent
# 4   -20.030579   APEX   absent
# ..         ...    ...      ...
# 336 -12.346708   APEX  present
# 337 -13.342991   APEX   absent
# 338  -4.273985   APEX   absent
# 339 -10.016541   APEX   absent
# 340  -2.042444   APEX   absent
#
# [341 rows x 7 columns]

# %%
X4d = embs[['dim1', 'dim2', 'dim3', 'dim4']].values

umap_instance = UMAP()

X2d = umap_instance.fit_transform(X4d)

# %%
# !pip3 list
# Out:
# Package                                   Version   Editable project location
# ----------------------------------------- --------- -----------------------------------------------------------------------------------
# 2022-jchavas-cingulate-inhibitory-control 0.0.1     /neurospin/dico/agaudin/Runs/05_rigourous/2022_jchavas_cingulate_inhibitory_control
# absl-py                                   0.15.0
# aiohttp                                   3.8.3
# aiosignal                                 1.2.0
# antlr4-python3-runtime                    4.9.3
# astunparse                                1.6.3
# async-timeout                             4.0.2
# asynctest                                 0.13.0
# attrs                                     22.1.0
# backcall                                  0.2.0
# bounded-pool-executor                     0.0.3
# cached-property                           1.5.2
# cachetools                                4.2.4
# certifi                                   2022.9.24
# charset-normalizer                        2.0.12
# clang                                     5.0
# cycler                                    0.11.0
# dataclasses                               0.8
# decorator                                 4.4.2
# entrypoints                               0.4
# flatbuffers                               1.12
# frozenlist                                1.2.0
# fsspec                                    2022.1.0
# future                                    0.18.2
# gast                                      0.4.0
# google-auth                               1.35.0
# google-auth-oauthlib                      0.4.6
# google-pasta                              0.2.0
# grpcio                                    1.48.2
# h5py                                      3.1.0
# Hydra                                     2.5
# hydra-core                                1.2.0
# idna                                      3.4
# idna-ssl                                  1.1.0
# imageio                                   2.15.0
# importlib-metadata                        4.8.3
# importlib-resources                       5.4.0
# ipykernel                                 5.5.6
# ipython                                   7.16.3
# ipython-genutils                          0.2.0
# jedi                                      0.17.2
# joblib                                    1.1.1
# jupyter-client                            7.1.2
# jupyter-core                              4.9.2
# kaleido                                   0.2.1
# keras                                     2.6.0
# Keras-Preprocessing                       1.1.2
# kiwisolver                                1.3.1
# lightly                                   1.2.32
# lightly-utils                             0.0.2
# llvmlite                                  0.36.0
# Markdown                                  3.3.7
# matplotlib                                3.3.4
# multidict                                 5.2.0
# nest-asyncio                              1.5.6
# networkx                                  2.5.1
# numba                                     0.53.1
# numexpr                                   2.8.1
# numpy                                     1.19.5
# oauthlib                                  3.2.2
# omegaconf                                 2.2.3
# opt-einsum                                3.3.0
# orca                                      1.8
# packaging                                 21.3
# pandas                                    1.1.5
# parso                                     0.7.1
# patsy                                     0.5.3
# pexpect                                   4.8.0
# pickleshare                               0.7.5
# Pillow                                    8.4.0
# pip                                       21.3.1
# pkg_resources                             0.0.0
# plotly                                    5.10.0
# pqdm                                      0.2.0
# prompt-toolkit                            3.0.31
# protobuf                                  3.19.6
# psutil                                    5.9.3
# ptyprocess                                0.7.0
# pyasn1                                    0.4.8
# pyasn1-modules                            0.2.8
# pyDeprecate                               0.3.1
# Pygments                                  2.13.0
# pynndescent                               0.5.7
# pyparsing                                 3.0.9
# python-dateutil                           2.8.2
# pytorch-lightning                         1.5.10
# pytorch-ssim                              0.1
# pytz                                      2022.5
# PyWavelets                                1.1.1
# PyYAML                                    6.0
# pyzmq                                     24.0.1
# requests                                  2.27.1
# requests-oauthlib                         1.3.1
# rsa                                       4.9
# scikit-image                              0.17.2
# scikit-learn                              0.24.2
# scipy                                     1.5.4
# seaborn                                   0.11.2
# setuptools                                59.5.0
# six                                       1.15.0
# sklearn                                   0.0
# statsmodels                               0.12.2
# tables                                    3.7.0
# tenacity                                  8.1.0
# tensorboard                               2.6.0
# tensorboard-data-server                   0.6.1
# tensorboard-plugin-wit                    1.8.1
# tensorflow                                2.6.2
# tensorflow-estimator                      2.6.0
# termcolor                                 1.1.0
# threadpoolctl                             3.1.0
# tifffile                                  2020.9.3
# toolz                                     0.12.0
# torch                                     1.10.1
# torch-summary                             1.4.5
# torchmetrics                              0.8.2
# torchvision                               0.11.2
# tornado                                   6.1
# tqdm                                      4.64.1
# traitlets                                 4.3.3
# typing-extensions                         3.7.4.3
# umap-learn                                0.5.3
# urllib3                                   1.26.12
# wcwidth                                   0.2.5
# Werkzeug                                  2.0.3
# wheel                                     0.37.1
# wrapt                                     1.12.1
# yarl                                      1.7.2
# zipp                                      3.6.0

# %%
plt.figure(figsize=(14,9.6))
plt.subplot(2,2,1)

color_dico = {'absent': 'lightgreen', 'present': 'red', 'proeminent': 'blue'}
colors1 = embs.PCGS.copy().map(color_dico)
#alphas = 0.5 + 0.5*(colors1 == 'blue')


plt.scatter(X2d[:,0], X2d[:,1], c=colors1)

plt.subplot(2,2,2)

sources = embs.source.copy()
colors2 = sources.map(base_dico)
plt.scatter(X2d[:,0], X2d[:,1], c=colors2, cmap='prism')

plt.subplot(2,2,3)
colors3 = (embs.PCGS != 'absent').astype(int)
plt.scatter(X2d[:,0], X2d[:,1], c=colors3, cmap='tab20', alpha=0.6)

# %%
(0.5*(colors1 == 'blue') + 0.5).unique()
# Out:
# array([0.5, 1. ])

# %%
paracingulate = embs[(embs.PCGS != 'absent')]
paracingulate
# Out:
#                                        ID       dim1      dim2       dim3  \
# 0                            1-03HUBJO_t0  13.746984  6.940231  -8.988678
# 1                            1-08ANDTI_t0  10.039248  3.071566 -23.064545
# 2                            1-11LEBJO_t0  15.008720  1.371084 -23.351560
# 8                            1-40AYMJU_t0  13.348683  2.567106  -7.711266
# 10                           2-04HEBTO_t0   6.194181  5.950728 -13.041893
# ..                                    ...        ...       ...        ...
# 328  sub-inhibition16_ses-pretraining_T1w  17.241695  9.896313 -11.753173
# 330  sub-inhibition18_ses-pretraining_T1w   8.915030  3.009636 -10.872553
# 332  sub-inhibition21_ses-pretraining_T1w  13.422213 -4.946096 -13.673832
# 333  sub-inhibition22_ses-pretraining_T1w   7.617312 -2.920372 -13.484284
# 336  sub-inhibition25_ses-pretraining_T1w   6.381626 -4.734384   0.285639
#
#           dim4 source     PCGS
# 0    -0.654266   APEX  present
# 1    -7.683618   APEX  present
# 2    -6.521302   APEX  present
# 8   -15.786127   APEX  present
# 10   -8.980822   APEX  present
# ..         ...    ...      ...
# 328  -2.983172   APEX  present
# 330  -3.116958   APEX  present
# 332  -3.483147   APEX  present
# 333   2.523840   APEX  present
# 336 -12.346708   APEX  present
#
# [144 rows x 7 columns]

# %%
X4d_pcgs = paracingulate[['dim1', 'dim2', 'dim3', 'dim4']].values

umap_instance = UMAP()

X2d_pcgs = umap_instance.fit_transform(X4d_pcgs)


plt.figure(figsize=(14,4.8))
plt.subplot(1,2,1)

color_dico = {'absent': 'lightgreen', 'present': 'red', 'proeminent': 'blue'}
colors1 = paracingulate.PCGS.copy().map(color_dico)

plt.scatter(X2d_pcgs[:,0], X2d_pcgs[:,1], c=colors1)

plt.subplot(1,2,2)

sources = paracingulate.source.copy()
colors2 = sources.map(base_dico)
plt.scatter(X2d_pcgs[:,0], X2d_pcgs[:,1], c=colors2, cmap='prism')

# %% [markdown]
# ## preds

# %%
model_preds = pd.read_csv("/neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-09-30/17-27-31/cingulate_ACCpatterns_embeddings/cross_val_predicted_labels.csv")
model_preds
# Out:
#                                   Subject  label  predicted_0  predicted_1  \
# 0                            1-03HUBJO_t0      1     0.830164     0.838776
# 1                            1-08ANDTI_t0      1     0.369626     0.362385
# 2                            1-11LEBJO_t0      1     0.640910     0.632905
# 3                            1-15LEHMI_t0      0     0.641753     0.642373
# 4                            1-17COLMA_t0      0     0.047369     0.066731
# ..                                    ...    ...          ...          ...
# 336  sub-inhibition25_ses-pretraining_T1w      1     1.067993     1.060506
# 337  sub-inhibition26_ses-pretraining_T1w      0     0.595698     0.601336
# 338  sub-inhibition28_ses-pretraining_T1w      0     0.339621     0.313370
# 339  sub-inhibition29_ses-pretraining_T1w      0     0.064906     0.064122
# 340  sub-inhibition31_ses-pretraining_T1w      0    -0.084179    -0.112649
#
#      predicted_2  predicted_3  predicted_4  predicted_5  predicted_6  \
# 0       0.890083     0.925888     0.840117     0.827103     0.848114
# 1       0.457208     0.513366     0.358877     0.315664     0.362087
# 2       0.723779     0.806229     0.636808     0.585200     0.635810
# 3       0.716817     0.818855     0.651825     0.585916     0.640340
# 4       0.143638     0.162476     0.048467     0.023104     0.056668
# ..           ...          ...          ...          ...          ...
# 336     1.017556     1.045652     1.060995     0.988770     1.058847
# 337     0.576278     0.582734     0.594495     0.536030     0.587206
# 338     0.362751     0.290567     0.282609     0.300626     0.293809
# 339     0.112965     0.022802     0.006882    -0.000426     0.022739
# 340    -0.016830    -0.146341    -0.169269    -0.114906    -0.148380
#
#      predicted_7  ...  predicted_242  predicted_243  predicted_244  \
# 0       0.816503  ...       0.897290       0.861490       0.820605
# 1       0.342210  ...       0.471584       0.352730       0.354164
# 2       0.607855  ...       0.739270       0.636497       0.610808
# 3       0.630174  ...       0.745380       0.645110       0.625144
# 4       0.056816  ...       0.167477       0.048908       0.083121
# ..           ...  ...            ...            ...            ...
# 336     1.030168  ...       1.068690       1.051355       1.004731
# 337     0.562864  ...       0.601766       0.585679       0.535052
# 338     0.274625  ...       0.331862       0.353803       0.295512
# 339    -0.011566  ...       0.061805       0.082695      -0.005948
# 340    -0.169019  ...      -0.095500      -0.053131      -0.128894
#
#      predicted_245  predicted_246  predicted_247  predicted_248  \
# 0         0.853469       0.820450       0.843945       0.856171
# 1         0.367566       0.327053       0.368821       0.399516
# 2         0.642388       0.591253       0.632634       0.664966
# 3         0.651645       0.624228       0.684866       0.720035
# 4         0.071035       0.068479       0.128598       0.154618
# ..             ...            ...            ...            ...
# 336       1.065825       1.047341       1.005251       1.056299
# 337       0.606377       0.594043       0.541571       0.580498
# 338       0.345919       0.317102       0.283820       0.330521
# 339       0.098783       0.054150      -0.014580       0.060932
# 340      -0.064669      -0.106106      -0.146856      -0.089431
#
#      predicted_249  median_pred  mean_pred
# 0         0.873362     0.857622   0.860126
# 1         0.444159     0.383377   0.389815
# 2         0.716476     0.657397   0.663796
# 3         0.696792     0.684315   0.688985
# 4         0.098723     0.104503   0.103056
# ..             ...          ...        ...
# 336       0.995413     1.034217   1.034696
# 337       0.570606     0.576714   0.575516
# 338       0.305747     0.317431   0.317046
# 339       0.046165     0.051455   0.045690
# 340      -0.098818    -0.103549  -0.101783
#
# [341 rows x 254 columns]

# %%
color_dico = {'absent': 'blue', 'present': 'red', 'proeminent': 'purple'}
colors = embs.PCGS.copy()
colors = colors.map(color_dico)

bins = np.arange(-0.7,1.5,0.05)

for key in color_dico.keys():
    alpha = 1 if key == 'proeminent' else 0.5
    plt.hist(model_preds[embs.PCGS == key].median_pred, bins=bins, color=color_dico[key], alpha=alpha)
