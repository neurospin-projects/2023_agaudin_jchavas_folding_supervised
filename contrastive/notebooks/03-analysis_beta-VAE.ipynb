# %% [markdown]
# Notebook to preprocess and display classifiers results for the beta-VAEs computed by Louise.

# %%
import os
import json
import pandas as pd
import numpy as np

from scipy.stats import ttest_ind

from contrastive.utils.models_database import
 import_bdd

# %% [markdown]
# ## Get ACCpatterns1 from ACCpatterns embeddings

# %%
acc0_subjects = pd.read_csv("/neurospin/dico/data/deep_folding/current/datasets/ACCpatterns/ACCpatterns_1_subject.csv")
acc0_subjects
# Out:
#                                   Subject
# 0                            1-20FORHU_t0
# 1                            1-23CREES_t0
# 2                            2-02FERMA_t0
# 3                            2-04HEBTO_t0
# 4                            2-08BESAG_t0
# ..                                    ...
# 166  sub-inhibition23_ses-pretraining_T1w
# 167  sub-inhibition24_ses-pretraining_T1w
# 168  sub-inhibition25_ses-pretraining_T1w
# 169  sub-inhibition28_ses-pretraining_T1w
# 170  sub-inhibition31_ses-pretraining_T1w
#
# [171 rows x 1 columns]

# %%
def get_acc0_embs(embs_path, acc0_embs_path, acc0_subjects=acc0_subjects):
    embs = pd.read_csv(embs_path, index_col=0)
    acc0_embs = embs[embs.index.isin(acc0_subjects.Subject.values)]
    acc0_embs.sort_index(inplace=True)

    # save the acc0 embeddings
    folder_path = '/' + os.path.join(*acc0_embs_path.split('/')[:-1])
    if not os.path.exists(folder_path):
        os.mkdir(folder_path)
    acc0_embs.to_csv(acc0_embs_path)
    return acc0_embs

# %%
# for i in range(1,6):
#     embs_path = f"/neurospin/dico/deep_folding/papers/ipmi2023/models/beta-VAE/n_30/#{i}/full_embeddings.csv"
#     acc0_embs_path = '/' + os.path.join(*embs_path.split('/')[:-1]) + '/cingulate_ACCpatterns_1_embeddings/full_embeddings.csv'

#     get_acc0_embs(embs_path, acc0_embs_path)

# %% [markdown]
# ## Resume beta-VAE results

# %% [markdown]
# Visualisation of the latent spaces in latent_space_visualization.ipynb

# %%
# compute and plot the dataframe of beta-VAE performances

folder_path = "/neurospin/dico/data/deep_folding/papers/ipmi2023/models/beta-VAE"
dims = [4, 10, 30]
dataset = 'cingulate_ACCpatterns_1'

df = pd.DataFrame(np.zeros((3,1)), index=dims, columns=['beta-VAE'])
std_df = pd.DataFrame(np.zeros((3,1)), index=dims, columns=['beta-VAE'])
bdd = pd.DataFrame(np.zeros((5*len(dims),2)),
                   columns=['num_representation_features', 'auc'])
bdd = bdd.astype({'num_representation_features': int})

for k,dim in enumerate(dims):
    performances = []
    for i in range(1,6):
        values_file = folder_path + f'/n_{dim}/#{i}/{dataset}_embeddings/values.json'
        with open(values_file, 'r') as file:
            values = json.load(file)
            auc = values['cross_val_auc'][0]
            performances.append(auc)
            bdd.loc[5*k+i-1,"auc"] = auc
            bdd.loc[5*k+i-1,"num_representation_features"] = dim
    performances = np.array(performances)
    print(dim, performances)
    df.iloc[k,0] = performances.mean()
    std_df.iloc[k,0] = performances.std()

df
# Out:
# 4 [0.6554241  0.68284149 0.47161867 0.66941963 0.68141515]
# 10 [0.64443584 0.72822729 0.70554459 0.64963629 0.69878921]
# 30 [0.63314677 0.62513894 0.64832541 0.60871065 0.64623036]
#     beta-VAE
# 4   0.632144
# 10  0.685327
# 30  0.632310

# %%
bdd = bdd.astype({'num_representation_features': str})

# %%
bdd.head()
# Out:
#   num_representation_features       auc
# 0                           4  0.655424
# 1                           4  0.682841
# 2                           4  0.471619
# 3                           4  0.669420
# 4                           4  0.681415

# %%
bdd.to_csv(f"{folder_path}/bdd_beta-VAE_evaluation-ACCpatterns-1.csv",
            index=False)

# %%
std_df
# Out:
#     beta-VAE
# 4   0.080867
# 10  0.032791
# 30  0.014556

# %% [markdown]
# ## Comparison with SimCLR convnet

# %%
bdd = import_bdd("/neurospin/dico/agaudin/Runs/new_bdd_models_0.csv")
convnets = bdd[(bdd.temperature == 0.1) & (bdd.drop_rate == 0.05) & (bdd.backbone_name == 'convnet')]
convnets
# Out:
#                                            model_path       auc   auc_std  \
# 88  /neurospin/dico/agaudin/Runs/04_pointnet/Outpu...  0.778832  0.003020
# 89  /neurospin/dico/agaudin/Runs/04_pointnet/Outpu...  0.776295  0.005263
# 34  /neurospin/dico/agaudin/Runs/04_pointnet/Outpu...  0.760827  0.004171
# 66  /neurospin/dico/agaudin/Runs/04_pointnet/Outpu...  0.749497  0.005254
# 91  /neurospin/dico/agaudin/Runs/04_pointnet/Outpu...  0.745395  0.008467
# 53  /neurospin/dico/agaudin/Runs/04_pointnet/Outpu...  0.742650  0.001482
# 45  /neurospin/dico/agaudin/Runs/04_pointnet/Outpu...  0.740142  0.013671
# 54  /neurospin/dico/agaudin/Runs/04_pointnet/Outpu...  0.736406  0.003110
# 44  /neurospin/dico/agaudin/Runs/04_pointnet/Outpu...  0.734367  0.004978
# 90  /neurospin/dico/agaudin/Runs/04_pointnet/Outpu...  0.729305  0.006410
# 87  /neurospin/dico/agaudin/Runs/04_pointnet/Outpu...  0.728514  0.005648
# 73  /neurospin/dico/agaudin/Runs/04_pointnet/Outpu...  0.717324  0.002373
# 81  /neurospin/dico/agaudin/Runs/04_pointnet/Outpu...  0.714440  0.000683
# 71  /neurospin/dico/agaudin/Runs/04_pointnet/Outpu...  0.714239  0.003233
# 72  /neurospin/dico/agaudin/Runs/04_pointnet/Outpu...  0.710101  0.003884
# 65  /neurospin/dico/agaudin/Runs/04_pointnet/Outpu...  0.700608  0.001197
# 70  /neurospin/dico/agaudin/Runs/04_pointnet/Outpu...  0.695224  0.005131
# 67  /neurospin/dico/agaudin/Runs/04_pointnet/Outpu...  0.694851  0.005050
# 64  /neurospin/dico/agaudin/Runs/04_pointnet/Outpu...  0.694609  0.007712
# 55  /neurospin/dico/agaudin/Runs/04_pointnet/Outpu...  0.693189  0.001970
# 56  /neurospin/dico/agaudin/Runs/04_pointnet/Outpu...  0.672743  0.009191
# 69  /neurospin/dico/agaudin/Runs/04_pointnet/Outpu...  0.668497  0.004951
# 43  /neurospin/dico/agaudin/Runs/04_pointnet/Outpu...  0.664698  0.007197
# 68  /neurospin/dico/agaudin/Runs/04_pointnet/Outpu...  0.662166  0.004710
# 6   /neurospin/dico/agaudin/Runs/04_pointnet/Outpu...  0.644389  0.046141
# 7   /neurospin/dico/agaudin/Runs/04_pointnet/Outpu...  0.523644  0.067874
#
#     accuracy  accuracy_std backbone_name  batch_size  drop_rate  \
# 88  0.721976      0.010526       convnet          16       0.05
# 89  0.748871      0.009153       convnet          16       0.05
# 34  0.703388      0.013148       convnet          16       0.05
# 66  0.668212      0.009069       convnet          16       0.05
# 91  0.671365      0.011422       convnet          16       0.05
# 53  0.662259      0.008020       convnet          16       0.05
# 45  0.694188      0.017061       convnet          16       0.05
# 54  0.698071      0.006667       convnet          16       0.05
# 44  0.707529      0.010938       convnet          16       0.05
# 90  0.673506      0.014100       convnet          16       0.05
# 87  0.666306      0.012414       convnet          16       0.05
# 73  0.663976      0.007671       convnet          16       0.05
# 81  0.665365      0.003042       convnet          16       0.05
# 71  0.648165      0.009339       convnet          16       0.05
# 72  0.652965      0.007262       convnet          16       0.05
# 65  0.666141      0.005545       convnet          16       0.05
# 70  0.639929      0.012593       convnet          16       0.05
# 67  0.660541      0.013819       convnet          16       0.05
# 64  0.665012      0.012889       convnet          16       0.05
# 55  0.658353      0.005548       convnet          16       0.05
# 56  0.656494      0.012538       convnet          16       0.05
# 69  0.613035      0.008238       convnet          16       0.05
# 43  0.637388      0.006627       convnet          16       0.05
# 68  0.647247      0.007890       convnet          16       0.05
# 6   0.609294      0.034834       convnet          16       0.05
# 7   0.530071      0.050680       convnet          16       0.05
#
#     early_stopping_patience  foldlabel  ...  num_outputs  \
# 88                      100       True  ...           10
# 89                      100       True  ...           10
# 34                      100       True  ...            4
# 66                      100      False  ...           30
# 91                      100       True  ...           10
# 53                      100       True  ...            4
# 45                      100       True  ...            4
# 54                      100       True  ...            4
# 44                      100      False  ...            4
# 90                      100       True  ...           10
# 87                      100       True  ...           10
# 73                      100       True  ...           30
# 81                      100       True  ...            4
# 71                      100       True  ...           30
# 72                      100       True  ...           30
# 65                      100      False  ...            4
# 70                      100      False  ...           30
# 67                      100      False  ...           30
# 64                      100      False  ...            4
# 55                      100      False  ...            4
# 56                      100      False  ...            4
# 69                      100      False  ...           30
# 43                      100      False  ...            4
# 68                      100      False  ...           30
# 6                       100       True  ...           30
# 7                       100       True  ...           30
#
#     num_representation_features  temperature  temperature_initial  train_loss  \
# 88                           10          0.1                  0.1    0.433261
# 89                           10          0.1                  0.1    0.462120
# 34                            4          0.1                  0.1    1.240257
# 66                           30          0.1                  0.1    0.086302
# 91                           10          0.1                  0.1    0.442286
# 53                            4          0.1                  0.1    1.374010
# 45                            4          0.1                  0.1    1.954553
# 54                            4          0.1                  0.1    1.251985
# 44                            4          0.1                  0.1    1.020133
# 90                           10          0.1                  0.1    0.416806
# 87                           10          0.1                  0.1    0.460650
# 73                           30          0.1                  0.1    0.179589
# 81                            4          0.1                  0.1    1.311802
# 71                           30          0.1                  0.1    0.161351
# 72                           30          0.1                  0.1    0.146027
# 65                            4          0.1                  0.1    1.371057
# 70                           30          0.1                  0.1    0.073816
# 67                           30          0.1                  0.1    0.070508
# 64                            4          0.1                  0.1    1.801281
# 55                            4          0.1                  0.1    1.115199
# 56                            4          0.1                  0.1    1.745262
# 69                           30          0.1                  0.1    0.078508
# 43                            4          0.1                  0.1    2.430351
# 68                           30          0.1                  0.1    0.071478
# 6                            30          0.1                  0.1    0.178311
# 7                            30          0.1                  0.1    0.218518
#
#     val_loss  exclude  0.1_quantile          dataset_name      git_branch
# 88  0.736669    False           NaN  cingulate_HCP_half_1  Run_03_aymeric
# 89  0.800465    False           NaN  cingulate_HCP_half_1  Run_03_aymeric
# 34  1.669160    False      0.078811  cingulate_HCP_half_1  Run_03_aymeric
# 66  0.153539    False     -0.147380  cingulate_HCP_half_1  Run_03_aymeric
# 91  0.582167    False           NaN  cingulate_HCP_half_1  Run_03_aymeric
# 53  1.463949    False      0.199899  cingulate_HCP_half_1  Run_03_aymeric
# 45  2.959328    False      0.652514  cingulate_HCP_half_1  Run_03_aymeric
# 54  1.929024    False      0.594088  cingulate_HCP_half_1  Run_03_aymeric
# 44  1.204887    False      0.319042  cingulate_HCP_half_1  Run_03_aymeric
# 90  0.869529    False           NaN  cingulate_HCP_half_1  Run_03_aymeric
# 87  0.601095    False           NaN  cingulate_HCP_half_1  Run_03_aymeric
# 73  0.328815    False      0.258330  cingulate_HCP_half_1  Run_03_aymeric
# 81  1.524517    False     -0.070515  cingulate_HCP_half_1  Run_03_aymeric
# 71  0.364222    False      0.221047  cingulate_HCP_half_1  Run_03_aymeric
# 72  0.436746    False      0.234082  cingulate_HCP_half_1  Run_03_aymeric
# 65  1.272551    False     -0.526808  cingulate_HCP_half_1  Run_03_aymeric
# 70  0.157736    False     -0.173430  cingulate_HCP_half_1  Run_03_aymeric
# 67  0.114356    False     -0.126232  cingulate_HCP_half_1  Run_03_aymeric
# 64  1.665524    False      0.441741  cingulate_HCP_half_1  Run_03_aymeric
# 55  1.120735    False      0.384894  cingulate_HCP_half_1  Run_03_aymeric
# 56  1.695547    False     -0.202789  cingulate_HCP_half_1  Run_03_aymeric
# 69  0.108472    False     -0.173340  cingulate_HCP_half_1  Run_03_aymeric
# 43  2.308953    False     -0.021801  cingulate_HCP_half_1  Run_03_aymeric
# 68  0.159583    False     -0.130877  cingulate_HCP_half_1  Run_03_aymeric
# 6   0.599187    False     -0.219919  cingulate_HCP_half_1  Run_03_aymeric
# 7   0.478270    False     -0.275497  cingulate_HCP_half_1  Run_03_aymeric
#
# [26 rows x 23 columns]

# %%
dataset = 'cingulate_ACCpatterns_0'

dims = [4, 10, 30]
foldlabels = [True, False]

for dim in dims:
    # load beta-VAE perf
    beta_VAE_perfs = []
    for i in range(1,6):
        values_file = folder_path + f'/n_{dim}/#{i}/{dataset}_embeddings/values.json'
        with open(values_file, 'r') as file:
            values = json.load(file)
            beta_VAE_perfs.append(values['cross_val_auc'][0])
    beta_VAE_perfs = np.array(beta_VAE_perfs)

    for foldlabel in foldlabels:
        # load SimCLR perfs
        SimCLR_perfs = convnets[(convnets.num_representation_features == dim) & (convnets.foldlabel == foldlabel)].auc

        # compute ttest
        print("Conditions:", dim, foldlabel)
        print("Performances: beta-VAE", beta_VAE_perfs.mean(), "; SimCLR", SimCLR_perfs.mean())
        print(ttest_ind(beta_VAE_perfs, SimCLR_perfs, equal_var=False))
        print("")
# Out:
# Conditions: 4 True
# Performances: beta-VAE 0.7136981078389529 ; SimCLR 0.7388929292929293
# Ttest_indResult(statistic=-2.9871399489719495, pvalue=0.023669163048992123)
#
# Conditions: 4 False
# Performances: beta-VAE 0.7136981078389529 ; SimCLR 0.6933689951154739
# Ttest_indResult(statistic=1.8915646273774136, pvalue=0.10341873786471027)
#
# Conditions: 10 True
# Performances: beta-VAE 0.7163735381988904 ; SimCLR 0.7516682316118934
# Ttest_indResult(statistic=-2.46840808108888, pvalue=0.03977247083201307)
#
# Conditions: 10 False
# Performances: beta-VAE 0.7163735381988904 ; SimCLR nan
# Ttest_indResult(statistic=nan, pvalue=nan)
#
# Conditions: 30 True
# Performances: beta-VAE 0.6741881917769241 ; SimCLR 0.6619396215677906
# Ttest_indResult(statistic=0.29954619717257025, pvalue=0.7752644001402708)
#
# Conditions: 30 False
# Performances: beta-VAE 0.6741881917769241 ; SimCLR 0.6940471759852042
# Ttest_indResult(statistic=-0.8613748121764792, pvalue=0.4143813077524445)
