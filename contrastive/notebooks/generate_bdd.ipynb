# %%
import os
import pandas as pd
import json
import yaml
import numpy as np
from datetime import datetime

from contrastive.utils.models_database import *

# %%
folders = ["/neurospin/dico/agaudin/Runs/04_pointnet/Output", "/neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/convnet",
"/neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/densenet2", "/neurospin/dico/agaudin/Runs/03_monkeys/Output/convnet_exploration"]
bdd = []
visited = []
dataset='cingulate_ACCpatterns'

generate_bdd_models(folders, bdd, visited, verbose=False, dataset=dataset)

len(bdd)
# Out:
# /neurospin/dico/agaudin/Runs/03_monkeys/Output/convnet_exploration not associated to a model. Continue
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/convnet_exploration/1mm_no_30
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/convnet_exploration/base3
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/convnet_exploration/1mm_fold_30
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/convnet_exploration/1mm_no_4
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/convnet_exploration/base1
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/convnet_exploration/drop_rate_0
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/convnet_exploration/base2
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/convnet_exploration/T_0.01
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/convnet_exploration/batch_size_4
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/convnet_exploration/1mm_no_4(2)
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/convnet_exploration/joel_30
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/convnet_exploration/batch_size_64
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/convnet_exploration/T_0.5
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/convnet_exploration/drop_rate_0.3
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/convnet_exploration/T_1
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/convnet_exploration/drop_rate_0.6
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/convnet_exploration/1mm_fold_4
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/convnet_exploration/joel_4
# /neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/densenet2 not associated to a model. Continue
# /neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/densenet2/foldlabel_30 not associated to a model. Continue
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/densenet2/foldlabel_30/09-12-48
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/densenet2/foldlabel_30/09-11-38
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/densenet2/foldlabel_30/11-15-47
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/densenet2/foldlabel_30/10-30-00
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/densenet2/foldlabel_30/14-56-33
# /neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/densenet2/no_foldlabel_4 not associated to a model. Continue
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/densenet2/no_foldlabel_4/15-20-30
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/densenet2/no_foldlabel_4/11-41-24
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/densenet2/no_foldlabel_4/12-24-13
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/densenet2/no_foldlabel_4/16-05-40
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/densenet2/no_foldlabel_4/16-29-57
# /neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/densenet2/no_foldlabel_30 not associated to a model. Continue
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/densenet2/no_foldlabel_30/16-16-33
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/densenet2/no_foldlabel_30/11-13-48
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/densenet2/no_foldlabel_30/09-15-52
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/densenet2/no_foldlabel_30/14-54-07
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/densenet2/no_foldlabel_30/11-40-43
# /neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/densenet2/foldlabel_4 not associated to a model. Continue
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/densenet2/foldlabel_4/12-22-46
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/densenet2/foldlabel_4/17-15-16
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/densenet2/foldlabel_4/09-25-59
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/densenet2/foldlabel_4/15-57-18
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/densenet2/foldlabel_4/10-29-24
# /neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/convnet not associated to a model. Continue
# /neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/convnet/foldlabel_30 not associated to a model. Continue
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/convnet/foldlabel_30/2022-07-05
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/convnet/foldlabel_30/13-51-11
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/convnet/foldlabel_30/11-19-12
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/convnet/foldlabel_30/09-02-52
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/convnet/foldlabel_30/11-55-03
# /neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/convnet/no_foldlabel_4 not associated to a model. Continue
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/convnet/no_foldlabel_4/2022-07-05
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/convnet/no_foldlabel_4/13-51-38
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/convnet/no_foldlabel_4/16-38-27
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/convnet/no_foldlabel_4/13-22-37
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/convnet/no_foldlabel_4/&14-21-26
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/convnet/no_foldlabel_4/13-12-53
# /neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/convnet/no_foldlabel_30 not associated to a model. Continue
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/convnet/no_foldlabel_30/2022-07-05
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/convnet/no_foldlabel_30/12-13-53
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/convnet/no_foldlabel_30/13-15-48
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/convnet/no_foldlabel_30/16-39-35
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/convnet/no_foldlabel_30/13-53-05
# /neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/convnet/foldlabel_4 not associated to a model. Continue
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/convnet/foldlabel_4/2022-07-05
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/convnet/foldlabel_4/&14-59-50
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/convnet/foldlabel_4/11-33-53
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/convnet/foldlabel_4/11-30-32
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/convnet/foldlabel_4/14-26-31
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/convnet/foldlabel_4/12-02-58
# /neurospin/dico/agaudin/Runs/04_pointnet/Output not associated to a model. Continue
# /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-10-03 not associated to a model. Continue
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-10-03/09-58-37
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-10-03/11-49-51
# /neurospin/dico/agaudin/Runs/04_pointnet/Output/pointnet not associated to a model. Continue
# /neurospin/dico/agaudin/Runs/04_pointnet/Output/pointnet/file_fold_30_drop_rate=0.05 not associated to a model. Continue
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/pointnet/file_fold_30_drop_rate=0.05/fold_30_drop_rate=0.05
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/pointnet/file_fold_30_drop_rate=0.05/fold_30_drop_rate=0.05_(5)
# /neurospin/dico/agaudin/Runs/04_pointnet/Output/pointnet/file_fold_30_drop_rate=0.05/#nn not associated to a model. Continue
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/pointnet/file_fold_30_drop_rate=0.05/fold_30_drop_rate=0.05_(1)
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/pointnet/file_fold_30_drop_rate=0.05/fold_30_drop_rate=0.05_(2)
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/pointnet/file_fold_30_drop_rate=0.05/fold_30_drop_rate=0.05_(4)
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/pointnet/file_fold_30_drop_rate=0.05/fold_30_drop_rate=0.05_(3)
# /neurospin/dico/agaudin/Runs/04_pointnet/Output/pointnet/file_no_30 not associated to a model. Continue
# /neurospin/dico/agaudin/Runs/04_pointnet/Output/pointnet/file_no_30/#nn not associated to a model. Continue
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/pointnet/file_no_30/no_30_(2)
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/pointnet/file_no_30/no_30
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/pointnet/fold_30_(2)
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/pointnet/fold_30
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/pointnet/fold_30_T=0.01
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/pointnet/fold_4_lr=8e-4
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/pointnet/no_4
# /neurospin/dico/agaudin/Runs/04_pointnet/Output/pointnet/file_no_30_drop_rate=0.05 not associated to a model. Continue
# /neurospin/dico/agaudin/Runs/04_pointnet/Output/pointnet/file_no_30_drop_rate=0.05/#nn not associated to a model. Continue
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/pointnet/file_no_30_drop_rate=0.05/10-28-55
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/pointnet/file_no_30_drop_rate=0.05/13-53-39
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/pointnet/file_no_30_drop_rate=0.05/no_30_drop_rate=0.05
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/pointnet/fold_30__batch_size=8e-4
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/pointnet/fold_30_lr=8e-4
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/pointnet/fold_30_T=0.5_(2)
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/pointnet/pointnet_no_12
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/pointnet/fold_30_drop_rate=0
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/pointnet/no_30_batch_size=8
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/pointnet/fold_30_drop_rate=0.1
# /neurospin/dico/agaudin/Runs/04_pointnet/Output/pointnet/file_fold_4_drop_rate=0.05 not associated to a model. Continue
# /neurospin/dico/agaudin/Runs/04_pointnet/Output/pointnet/file_fold_4_drop_rate=0.05/#nn not associated to a model. Continue
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/pointnet/file_fold_4_drop_rate=0.05/13-27-30
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/pointnet/file_fold_4_drop_rate=0.05/14-27-23
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/pointnet/file_fold_4_drop_rate=0.05/13-27-25
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/pointnet/file_fold_4_drop_rate=0.05/14-27-24
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/pointnet/file_fold_4_drop_rate=0.05/15-42-41
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/pointnet/fold_30_T=0.5
# /neurospin/dico/agaudin/Runs/04_pointnet/Output/pointnet/file_fold_30_drop_rate=0.05_HCPfull not associated to a model. Continue
# /neurospin/dico/agaudin/Runs/04_pointnet/Output/pointnet/file_fold_30_drop_rate=0.05_HCPfull/#nn not associated to a model. Continue
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/pointnet/file_fold_30_drop_rate=0.05_HCPfull/fold_30_drop_rate=0.05_HCP_full
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/pointnet/file_fold_30_drop_rate=0.05_HCPfull/fold_30_drop_rate=0.05_HCP_full_(3)
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/pointnet/file_fold_30_drop_rate=0.05_HCPfull/fold_30_drop_rate=0.05_HCP_full_(4)
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/pointnet/file_fold_30_drop_rate=0.05_HCPfull/fold_30_drop_rate=0.05_HCP_full_(5)
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/pointnet/file_fold_30_drop_rate=0.05_HCPfull/fold_30_drop_rate=0.05_HCP_full_(2)
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/pointnet/fold_30_drop_rate=0.3
# /neurospin/dico/agaudin/Runs/04_pointnet/Output/pointnet/file_fold_4_drop_rate=0.05_HCPfull not associated to a model. Continue
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/pointnet/file_fold_4_drop_rate=0.05_HCPfull/12-10-15
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/pointnet/file_fold_4_drop_rate=0.05_HCPfull/11-10-03
# /neurospin/dico/agaudin/Runs/04_pointnet/Output/pointnet/file_fold_4_drop_rate=0.05_HCPfull/#nn not associated to a model. Continue
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/pointnet/file_fold_4_drop_rate=0.05_HCPfull/10-45-10
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/pointnet/file_fold_4_drop_rate=0.05_HCPfull/09-19-57
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/pointnet/file_fold_4_drop_rate=0.05_HCPfull/09-47-47
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/pointnet/fold_4
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/pointnet/no_4_drop_rate=0.05
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/pointnet/no_30_drop_rate_0.1
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/pointnet/no_30_drop_rate=0
# /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-10-06 not associated to a model. Continue
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-10-06/11-12-30
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-10-06/17-57-58
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-10-06/09-38-17
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-10-06/11-13-05
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-10-06/19-32-12
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-10-06/18-58-23
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-10-06/14-56-06
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-10-06/14-56-39
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-10-06/19-45-55
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-10-06/20-26-42
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-10-06/20-52-23
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-10-06/20-20-23
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-10-06/19-21-12
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-10-06/18-02-12
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-10-06/17-03-55
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-10-06/09-39-07
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-10-06/11-50-18
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-10-06/19-47-08
# /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-10-04 not associated to a model. Continue
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-10-04/14-48-32
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-10-04/16-53-20
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-10-04/15-50-08
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-10-04/16-49-15
# /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-10-05 not associated to a model. Continue
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-10-05/15-42-29
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-10-05/11-06-06
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-10-05/11-05-36
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-10-05/13-55-26
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-10-05/15-47-37
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-10-05/13-53-04
# /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-08-04 not associated to a model. Continue
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-08-04/13-29-56
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-08-04/11-36-14
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-08-04/13-28-58
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-08-04/15-21-29
# /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-09-02 not associated to a model. Continue
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-09-02/11-05-34
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-09-02/pointnet_sigmoid_fold
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-09-02/pointnet_sigmoid_no
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-09-02/densenet_sigmoid_no
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-09-02/12-19-16
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-09-02/convnet_sigmoid_no
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-09-02/12-18-43
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-09-02/densenet_sigmoid_fold
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-09-02/09-28-35
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-09-02/convnet_sigmoid_fold
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-09-02/09-29-08
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-09-02/11-05-29
# /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-09-29 not associated to a model. Continue
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-09-29/09-09-48
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-09-29/15-34-10
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-09-29/11-29-34
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-09-29/10-11-12
# /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-09-01 not associated to a model. Continue
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-09-01/conv_(1)
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-09-01/conv_T=0.5_(3)
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-09-01/dense_(2)
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-09-01/conv_T=0.5
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-09-01/conv
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-09-01/dense
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-09-01/conv_T=0.5_(2)
# /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-10-07 not associated to a model. Continue
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-10-07/09-22-42_3
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-10-07/11-15-23_1
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-10-07/14-05-41
# Get the losses for /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-10-07/14-05-41.
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-10-07/14-05-41
# {'train_loss': 6.863670825958252, 'val_loss': 6.433454990386963}
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-10-07/13-58-28_0
# Get the losses for /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-10-07/13-58-28_0.
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-10-07/13-58-28_0
# {'train_loss': 0.3698243200778961, 'val_loss': 0.5599716901779175}
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-10-07/09-22-42_1
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-10-07/09-22-42_0
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-10-07/11-15-23_2
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-10-07/13-58-28_1
# Get the losses for /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-10-07/13-58-28_1.
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-10-07/13-58-28_1
# {'train_loss': 0.22922053933143616, 'val_loss': 0.3891342282295227}
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-10-07/09-22-42_2
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-10-07/11-15-23_0
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-10-07/11-29-40_1
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-10-07/09-22-42_4
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-10-07/14-29-14
# Get the losses for /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-10-07/14-29-14.
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-10-07/14-29-14
# {'train_loss': 1.311801791191101, 'val_loss': 1.5245165824890137}
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-10-07/14-14-16
# Get the losses for /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-10-07/14-14-16.
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-10-07/14-14-16
# {'train_loss': 2.403120756149292, 'val_loss': 2.404048442840576}
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-10-07/13-58-28_2
# Get the losses for /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-10-07/13-58-28_2.
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-10-07/13-58-28_2
# {'train_loss': 0.3291403353214264, 'val_loss': 0.5517234802246094}
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-10-07/11-29-40_0
# /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-09-30 not associated to a model. Continue
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-09-30/09-15-34
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-09-30/13-42-55
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-09-30/15-17-54
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-09-30/15-13-06
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-09-30/17-29-48
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-09-30/12-01-14
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-09-30/13-42-09
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-09-30/11-25-52
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-09-30/11-23-53
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-09-30/09-15-35
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-09-30/17-27-31
# /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-08-02 not associated to a model. Continue
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-08-02/joel_dense_T=0.1
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-08-02/joel_dense_T=0.1(2)
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-08-02/aymeric_dense_T=0.5(2)
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-08-02/aymeric_dense_T=0.5
# 192

# %%
bdd = pd.DataFrame(bdd)
bdd
# Out:
#                                             model_path       auc   auc_std  \
# 0    /neurospin/dico/agaudin/Runs/03_monkeys/Output...  0.582225  0.041573
# 1    /neurospin/dico/agaudin/Runs/03_monkeys/Output...  0.644770  0.040686
# 2    /neurospin/dico/agaudin/Runs/03_monkeys/Output...  0.586549  0.037230
# 3    /neurospin/dico/agaudin/Runs/03_monkeys/Output...  0.488471  0.035180
# 4    /neurospin/dico/agaudin/Runs/03_monkeys/Output...  0.673959  0.041645
# ..                                                 ...       ...       ...
# 187  /neurospin/dico/agaudin/Runs/04_pointnet/Outpu...  0.752147  0.003479
# 188  /neurospin/dico/agaudin/Runs/04_pointnet/Outpu...  0.493466  0.038922
# 189  /neurospin/dico/agaudin/Runs/04_pointnet/Outpu...  0.596988  0.039084
# 190  /neurospin/dico/agaudin/Runs/04_pointnet/Outpu...  0.490982  0.028938
# 191  /neurospin/dico/agaudin/Runs/04_pointnet/Outpu...  0.510331  0.031852
#
#      accuracy  accuracy_std backbone_name  batch_size  checkerboard_size  \
# 0    0.553138      0.043799       convnet          16                  4
# 1    0.610534      0.032800       convnet          16                  4
# 2    0.562088      0.034258       convnet          16                  4
# 3    0.548809      0.032750       convnet          16                  4
# 4    0.629466      0.034312       convnet          16                  4
# ..        ...           ...           ...         ...                ...
# 187  0.705150      0.009098       convnet          16                  4
# 188  0.503871      0.040189           NaN          16                  4
# 189  0.570522      0.037998           NaN          16                  4
# 190  0.525619      0.023270      densenet          16                  4
# 191  0.519238      0.030662      densenet          16                  4
#
#      depth_decoder  drop_rate  ...  with_labels train_loss  val_loss  exclude  \
# 0                3       0.15  ...        False   0.284891  0.219530    False
# 1                3       0.15  ...        False   0.321648  0.207814    False
# 2                3       0.15  ...        False   1.614107  2.995792    False
# 3                3       0.15  ...        False   3.643852  2.511922    False
# 4                3       0.15  ...        False   0.263300  0.285387    False
# ..             ...        ...  ...          ...        ...       ...      ...
# 187              3       0.05  ...        False   1.240257  1.669160    False
# 188              3       0.15  ...        False   0.483237  1.101275    False
# 189              3       0.15  ...        False   0.390795  0.520071    False
# 190              3       0.15  ...        False   3.791713  3.817966    False
# 191              3       0.15  ...        False   3.780218  3.786584    False
#
#     0.1_quantile  block_config  growth_rate  num_init_features  \
# 0       0.718123           NaN          NaN                NaN
# 1      -0.464945           NaN          NaN                NaN
# 2       0.334176           NaN          NaN                NaN
# 3       0.831983           NaN          NaN                NaN
# 4      -0.468021           NaN          NaN                NaN
# ..           ...           ...          ...                ...
# 187     0.078811           NaN          NaN                NaN
# 188     0.620462       [6, 16]         32.0               64.0
# 189     0.559707       [6, 16]         32.0               64.0
# 190    -0.021195       [6, 16]         32.0               64.0
# 191    -0.384964       [6, 16]         32.0               64.0
#
#              dataset_name   n_max
# 0                     NaN     NaN
# 1                     NaN     NaN
# 2                     NaN     NaN
# 3                     NaN     NaN
# 4                     NaN     NaN
# ..                    ...     ...
# 187  cingulate_HCP_half_1  1080.0
# 188                   NaN     NaN
# 189                   NaN     NaN
# 190                   NaN     NaN
# 191                   NaN     NaN
#
# [192 rows x 44 columns]

# %%
bdd = post_process_bdd_models(bdd, hard_remove=["partition", "patch_size", "block_config", "numpy_all"], git_branch=True)
bdd
# Out:
#                                             model_path       auc   auc_std  \
# 0    /neurospin/dico/agaudin/Runs/03_monkeys/Output...  0.595940  0.045925
# 1    /neurospin/dico/agaudin/Runs/03_monkeys/Output...  0.600870  0.040834
# 2    /neurospin/dico/agaudin/Runs/03_monkeys/Output...  0.659754  0.048348
# 3    /neurospin/dico/agaudin/Runs/03_monkeys/Output...  0.605214  0.042651
# 4    /neurospin/dico/agaudin/Runs/03_monkeys/Output...  0.606865  0.044687
# ..                                                 ...       ...       ...
# 187  /neurospin/dico/agaudin/Runs/04_pointnet/Outpu...  0.651585  0.001231
# 188  /neurospin/dico/agaudin/Runs/04_pointnet/Outpu...  0.627033  0.018632
# 189  /neurospin/dico/agaudin/Runs/04_pointnet/Outpu...  0.486872  0.025558
# 190  /neurospin/dico/agaudin/Runs/04_pointnet/Outpu...  0.463362  0.009882
# 191  /neurospin/dico/agaudin/Runs/04_pointnet/Outpu...  0.661034  0.009965
#
#      accuracy  accuracy_std backbone_name  batch_size  drop_rate  \
# 0    0.575977      0.035288       convnet          16       0.15
# 1    0.578182      0.038861       convnet          16       0.15
# 2    0.617584      0.042720       convnet          16       0.15
# 3    0.588129      0.037000       convnet          16       0.15
# 4    0.588305      0.037069       convnet          16       0.15
# ..        ...           ...           ...         ...        ...
# 187  0.622804      0.002003      pointnet          16       0.00
# 188  0.625161      0.012915      pointnet          16       0.10
# 189  0.577713      0.000000      pointnet          16       0.15
# 190  0.559331      0.002454      pointnet          16       0.05
# 191  0.649009      0.009482      pointnet          16       0.05
#
#      early_stopping_patience  foldlabel  ... num_outputs  \
# 0                        100       True  ...          30
# 1                        100       True  ...          30
# 2                        250       True  ...          30
# 3                        100       True  ...          30
# 4                        250       True  ...          30
# ..                       ...        ...  ...         ...
# 187                      100      False  ...          30
# 188                      100      False  ...          30
# 189                      100      False  ...           4
# 190                      100      False  ...           4
# 191                      100      False  ...          12
#
#      num_representation_features  temperature  temperature_initial  \
# 0                             30          0.1                  0.1
# 1                             30          0.1                  0.1
# 2                             30          0.1                  0.1
# 3                             30          0.1                  0.1
# 4                             30          0.1                  0.1
# ..                           ...          ...                  ...
# 187                           30          0.1                  0.1
# 188                           30          0.1                  0.1
# 189                            4          0.1                  0.1
# 190                            4          0.1                  0.1
# 191                           12          0.1                  0.1
#
#      train_loss  val_loss  exclude  0.1_quantile          dataset_name  \
# 0      0.349243  0.515141    False     -0.149932  cingulate_HCP_half_1
# 1      0.376334  0.615989    False     -0.214874  cingulate_HCP_half_1
# 2      0.416473  0.440377    False     -0.051465  cingulate_HCP_half_1
# 3      0.392093  0.608668    False     -0.354155  cingulate_HCP_half_1
# 4      0.330082  0.690635    False     -0.194344  cingulate_HCP_half_1
# ..          ...       ...      ...           ...                   ...
# 187    0.890107  0.724653    False     -0.357055  cingulate_HCP_half_1
# 188    1.952606  1.368340    False     -0.573413  cingulate_HCP_half_1
# 189    4.179968  3.784941    False     -0.562040  cingulate_HCP_half_1
# 190    3.744332  3.345133    False     -0.757010  cingulate_HCP_half_1
# 191    1.885288  1.574761    False     -0.638327  cingulate_HCP_half_1
#
#          git_branch
# 0    Run_03_aymeric
# 1    Run_03_aymeric
# 2    Run_03_aymeric
# 3    Run_03_aymeric
# 4    Run_03_aymeric
# ..              ...
# 187        pointnet
# 188        pointnet
# 189        pointnet
# 190        pointnet
# 191        pointnet
#
# [192 rows x 24 columns]

# %%
# save the database
save_path = "/neurospin/dico/agaudin/Runs/new_bdd_models.csv"
bdd.to_csv(save_path, index=True)

# write the little readme

with open("/neurospin/dico/agaudin/Runs/new_readme_bdd.txt", 'w') as file:
    file.write("Contient les paramètres de tous les modèles d'intérêt (dossiers précisés en-dessous). La base est faite en sorte que \
seuls les paramètres qui changent entre les modèles soient enregistrés.\n")
    file.write("\n")
    file.write("Généré avec contrastive/notebooks/generate_bdd.ipynb le " + datetime.now().strftime('%d/%m/%Y à %H:%M') + '.\n')
    file.write("\n")
    file.write("Dossiers utilisés : [")
    for folder in folders:
        file.write(folder)
        if folder == folders[-1]:
            file.write(']')
        else:
            file.write(',\n')
