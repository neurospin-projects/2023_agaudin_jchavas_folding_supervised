# %%
import os
import pandas as pd
import json
import yaml
import numpy as np

# %%
def get_subdirs(directory):
    sub_dirs = os.listdir(directory)
    sub_dirs = [os.path.join(directory, name) for name in sub_dirs]
    sub_dirs = [path for path in sub_dirs if os.path.isdir(path)]
    return sub_dirs

get_subdirs("/neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-08-02")
# Out:
# ['/neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-08-02/aymeric_dense_T=0.5',
#  '/neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-08-02/aymeric_dense_T=0.5(2)',
#  '/neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-08-02/joel_dense_T=0.1(2)',
#  '/neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-08-02/joel_dense_T=0.1']

# %%
def generate_bdd_models(folders, bdd_models, visited, dataset='cingulate_ACCpatterns', verbose=True):
    if verbose:
        print("Start", len(folders), len(bdd_models))

    while folders != []:
        # remove folders already treated
        folders = [folder for folder in folders if folder not in visited]
        
        # condition as folders can be emptied by the previous line
        if folders != []:
            dir_path = folders.pop()
            visited.append(dir_path)
            
            # checks if directory
            if os.path.isdir(dir_path):
                # check if directory associated to a model
                if os.path.exists(dir_path+'/.hydra/config.yaml'):
                    print("Treating", dir_path)
                    # check if values and parameters computed for the model
                    if os.path.exists(dir_path + f"/{dataset}_embeddings/values.json"):
                        model_dict = {}
                        model_dict['model_path'] = dir_path
                        # read performances
                        with open(dir_path + f"/{dataset}_embeddings/values.json", 'r') as file:
                            values = json.load(file)
                            decomposed_values = {'auc': values['cross_val_auc'][0],
                                                 'auc_std': values['cross_val_auc'][1],
                                                 'accuracy': values['cross_val_total_accuracy'][0],
                                                 'accuracy_std': values['cross_val_total_accuracy'][1]}
                            model_dict.update(decomposed_values)
                        # read parameters
                        with open(dir_path+'/partial_config.yaml', 'r') as file2:
                            partial_config = yaml.load(file2, Loader=yaml.FullLoader)
                            model_dict.update(partial_config)
                        bdd_models.append(model_dict)
                        if verbose:
                            print("End model", len(folders), len(bdd_models))

                    else:
                        print(f"Model does not have embeddings and their evaluation OR \
they are done with another database than {dataset}")

                else:
                    print(f"{dir_path} not associated to a model. Continue")
                    new_dirs = get_subdirs(dir_path)
                    folders.extend(new_dirs)
                    # remove folders already treated
                    folders = [folder for folder in folders if folder not in visited]
                    if verbose:
                        print("End recursive", len(folders), len(bdd_models))
                    
                    generate_bdd_models(folders, bdd_models, visited, dataset=dataset, verbose=verbose)
            
            else:
                print(f"{dir_path} is a file. Continue.")
                if verbose:
                    print("End file", len(bdd_models))

# %%
folders = ["/neurospin/dico/agaudin/Runs/04_pointnet/Output", "/neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/convnet",
"/neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/densenet2", "/neurospin/dico/agaudin/Runs/03_monkeys/Output/convnet_exploration"]
bdd_models = []
visited = []

generate_bdd_models(folders, bdd_models, visited, verbose=False)

len(bdd_models)
# Out:
# /neurospin/dico/agaudin/Runs/03_monkeys/Output/convnet_exploration not associated to a model. Continue
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/convnet_exploration/1mm_no_30
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/convnet_exploration/base3
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/convnet_exploration/1mm_fold_30
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/convnet_exploration/1mm_no_4
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/convnet_exploration/base1
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/convnet_exploration/drop_rate_0
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/convnet_exploration/base2
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/convnet_exploration/T_0.01
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/convnet_exploration/batch_size_4
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/convnet_exploration/1mm_no_4(2)
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/convnet_exploration/joel_30
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/convnet_exploration/batch_size_64
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/convnet_exploration/T_0.5
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/convnet_exploration/drop_rate_0.3
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/convnet_exploration/T_1
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/convnet_exploration/drop_rate_0.6
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/convnet_exploration/1mm_fold_4
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/convnet_exploration/joel_4
# /neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/densenet2 not associated to a model. Continue
# /neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/densenet2/foldlabel_30 not associated to a model. Continue
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/densenet2/foldlabel_30/09-12-48
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/densenet2/foldlabel_30/09-11-38
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/densenet2/foldlabel_30/11-15-47
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/densenet2/foldlabel_30/10-30-00
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/densenet2/foldlabel_30/14-56-33
# /neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/densenet2/no_foldlabel_4 not associated to a model. Continue
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/densenet2/no_foldlabel_4/15-20-30
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/densenet2/no_foldlabel_4/11-41-24
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/densenet2/no_foldlabel_4/12-24-13
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/densenet2/no_foldlabel_4/16-05-40
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/densenet2/no_foldlabel_4/16-29-57
# /neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/densenet2/no_foldlabel_30 not associated to a model. Continue
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/densenet2/no_foldlabel_30/16-16-33
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/densenet2/no_foldlabel_30/11-13-48
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/densenet2/no_foldlabel_30/09-15-52
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/densenet2/no_foldlabel_30/14-54-07
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/densenet2/no_foldlabel_30/11-40-43
# /neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/densenet2/foldlabel_4 not associated to a model. Continue
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/densenet2/foldlabel_4/12-22-46
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/densenet2/foldlabel_4/17-15-16
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/densenet2/foldlabel_4/09-25-59
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/densenet2/foldlabel_4/15-57-18
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/densenet2/foldlabel_4/10-29-24
# /neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/convnet not associated to a model. Continue
# /neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/convnet/foldlabel_30 not associated to a model. Continue
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/convnet/foldlabel_30/2022-07-05
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/convnet/foldlabel_30/13-51-11
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/convnet/foldlabel_30/11-19-12
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/convnet/foldlabel_30/09-02-52
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/convnet/foldlabel_30/11-55-03
# /neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/convnet/no_foldlabel_4 not associated to a model. Continue
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/convnet/no_foldlabel_4/2022-07-05
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/convnet/no_foldlabel_4/13-51-38
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/convnet/no_foldlabel_4/16-38-27
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/convnet/no_foldlabel_4/13-22-37
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/convnet/no_foldlabel_4/&14-21-26
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/convnet/no_foldlabel_4/13-12-53
# /neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/convnet/no_foldlabel_30 not associated to a model. Continue
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/convnet/no_foldlabel_30/2022-07-05
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/convnet/no_foldlabel_30/12-13-53
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/convnet/no_foldlabel_30/13-15-48
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/convnet/no_foldlabel_30/16-39-35
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/convnet/no_foldlabel_30/13-53-05
# /neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/convnet/foldlabel_4 not associated to a model. Continue
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/convnet/foldlabel_4/2022-07-05
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/convnet/foldlabel_4/&14-59-50
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/convnet/foldlabel_4/11-33-53
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/convnet/foldlabel_4/11-30-32
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/convnet/foldlabel_4/14-26-31
# Treating /neurospin/dico/agaudin/Runs/03_monkeys/Output/analysis_folders/convnet/foldlabel_4/12-02-58
# /neurospin/dico/agaudin/Runs/04_pointnet/Output not associated to a model. Continue
# /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-08-04 not associated to a model. Continue
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-08-04/13-29-56
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-08-04/11-36-14
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-08-04/13-28-58
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-08-04/15-21-29
# /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-08-02 not associated to a model. Continue
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-08-02/joel_dense_T=0.1
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-08-02/joel_dense_T=0.1(2)
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-08-02/aymeric_dense_T=0.5(2)
# Treating /neurospin/dico/agaudin/Runs/04_pointnet/Output/2022-08-02/aymeric_dense_T=0.5
# 68

# %%
bdd_models = pd.DataFrame(bdd_models)
bdd_models
# Out:
#                                            model_path       auc   auc_std  \
# 0   /neurospin/dico/agaudin/Runs/03_monkeys/Output...  0.582225  0.041573
# 1   /neurospin/dico/agaudin/Runs/03_monkeys/Output...  0.644770  0.040686
# 2   /neurospin/dico/agaudin/Runs/03_monkeys/Output...  0.586549  0.037230
# 3   /neurospin/dico/agaudin/Runs/03_monkeys/Output...  0.488471  0.035180
# 4   /neurospin/dico/agaudin/Runs/03_monkeys/Output...  0.673959  0.041645
# ..                                                ...       ...       ...
# 63  /neurospin/dico/agaudin/Runs/04_pointnet/Outpu...  0.576889  0.056377
# 64  /neurospin/dico/agaudin/Runs/04_pointnet/Outpu...  0.493466  0.038922
# 65  /neurospin/dico/agaudin/Runs/04_pointnet/Outpu...  0.596988  0.039084
# 66  /neurospin/dico/agaudin/Runs/04_pointnet/Outpu...  0.490982  0.028938
# 67  /neurospin/dico/agaudin/Runs/04_pointnet/Outpu...  0.510331  0.031852
#
#     accuracy  accuracy_std backbone_name  batch_size  checkerboard_size  \
# 0   0.553138      0.043799       convnet          16                  4
# 1   0.610534      0.032800       convnet          16                  4
# 2   0.562088      0.034258       convnet          16                  4
# 3   0.548809      0.032750       convnet          16                  4
# 4   0.629466      0.034312       convnet          16                  4
# ..       ...           ...           ...         ...                ...
# 63  0.567038      0.039782       convnet          16                  4
# 64  0.503871      0.040189           NaN          16                  4
# 65  0.570522      0.037998           NaN          16                  4
# 66  0.525619      0.023270      densenet          16                  4
# 67  0.519238      0.030662      densenet          16                  4
#
#     depth_decoder  drop_rate  ...  seed sigma  temperature  \
# 0               3       0.15  ...     1     5          0.1
# 1               3       0.15  ...     1     5          0.1
# 2               3       0.15  ...     1     5          0.1
# 3               3       0.15  ...     1     5          0.1
# 4               3       0.15  ...     1     5          0.1
# ..            ...        ...  ...   ...   ...          ...
# 63              3       0.15  ...     1     5          0.5
# 64              3       0.15  ...     1     5          0.1
# 65              3       0.15  ...     1     5          0.1
# 66              3       0.15  ...     1     5          0.5
# 67              3       0.15  ...     1     5          0.5
#
#     temperature_initial                                 train_val_csv_file  \
# 0                   0.1  /neurospin/dico/data/deep_folding/papers/midl2...
# 1                   0.1  /neurospin/dico/data/deep_folding/papers/midl2...
# 2                   0.1  /neurospin/dico/data/deep_folding/papers/midl2...
# 3                   0.1  /neurospin/dico/data/deep_folding/papers/midl2...
# 4                   0.1  /neurospin/dico/data/deep_folding/papers/midl2...
# ..                  ...                                                ...
# 63                  0.5                                                NaN
# 64                  0.1  /neurospin/dico/data/deep_folding/papers/midl2...
# 65                  0.1  /neurospin/dico/data/deep_folding/papers/midl2...
# 66                  0.5                                                NaN
# 67                  0.5                                                NaN
#
#     weight_decay  with_labels  block_config  growth_rate num_init_features
# 0        0.00005        False           NaN          NaN               NaN
# 1        0.00005        False           NaN          NaN               NaN
# 2        0.00005        False           NaN          NaN               NaN
# 3        0.00005        False           NaN          NaN               NaN
# 4        0.00005        False           NaN          NaN               NaN
# ..           ...          ...           ...          ...               ...
# 63       0.00005        False           NaN          NaN               NaN
# 64       0.00005        False       [6, 16]         32.0              64.0
# 65       0.00005        False       [6, 16]         32.0              64.0
# 66       0.00005        False       [6, 16]         32.0              64.0
# 67       0.00005        False       [6, 16]         32.0              64.0
#
# [68 rows x 38 columns]

# %%
def post_process_bdd_models(bdd_models, hard_remove=[]):
    # hard_remove contains columns you want to remove by hand
    bdd_models = bdd_models.drop(columns=hard_remove)

    # deal with '[' and ']'

    # specify git branch
    bdd_models['git_branch'] = 'Run_03_aymeric'
    bdd_models.loc[bdd_models.backbone_name.isna(), 'git_branch'] = 'Run_43_joel'


    # remove columns where the values never change
    remove = []
    for col in bdd_models.columns:
        col_values = bdd_models[col].dropna().unique()
        if len(col_values) <= 1:
            remove.append(col)
    bdd_models = bdd_models.drop(columns=remove)

    # sort by model_path
    bdd_models.sort_values(by="model_path", axis=0) # doesn't work I don't know why

    # sort columns by alphabetical order
    bdd_models.sort_index(axis=1)

    return bdd_models

# %%
bdd_models = post_process_bdd_models(bdd_models, hard_remove=["partition", "patch_size", "block_config"])
bdd_models
# Out:
# fin Index(['model_path', 'auc', 'auc_std', 'accuracy', 'accuracy_std',
#        'backbone_name', 'batch_size', 'drop_rate', 'early_stopping_patience',
#        'foldlabel', 'input_size', 'lr', 'max_angle', 'max_epochs',
#        'num_outputs', 'num_representation_features', 'numpy_all',
#        'temperature', 'temperature_initial', 'git_branch'],
#       dtype='object')
#                                            model_path       auc   auc_std  \
# 0   /neurospin/dico/agaudin/Runs/03_monkeys/Output...  0.582225  0.041573
# 1   /neurospin/dico/agaudin/Runs/03_monkeys/Output...  0.644770  0.040686
# 2   /neurospin/dico/agaudin/Runs/03_monkeys/Output...  0.586549  0.037230
# 3   /neurospin/dico/agaudin/Runs/03_monkeys/Output...  0.488471  0.035180
# 4   /neurospin/dico/agaudin/Runs/03_monkeys/Output...  0.673959  0.041645
# ..                                                ...       ...       ...
# 63  /neurospin/dico/agaudin/Runs/04_pointnet/Outpu...  0.576889  0.056377
# 64  /neurospin/dico/agaudin/Runs/04_pointnet/Outpu...  0.493466  0.038922
# 65  /neurospin/dico/agaudin/Runs/04_pointnet/Outpu...  0.596988  0.039084
# 66  /neurospin/dico/agaudin/Runs/04_pointnet/Outpu...  0.490982  0.028938
# 67  /neurospin/dico/agaudin/Runs/04_pointnet/Outpu...  0.510331  0.031852
#
#     accuracy  accuracy_std backbone_name  batch_size  drop_rate  \
# 0   0.553138      0.043799       convnet          16       0.15
# 1   0.610534      0.032800       convnet          16       0.15
# 2   0.562088      0.034258       convnet          16       0.15
# 3   0.548809      0.032750       convnet          16       0.15
# 4   0.629466      0.034312       convnet          16       0.15
# ..       ...           ...           ...         ...        ...
# 63  0.567038      0.039782       convnet          16       0.15
# 64  0.503871      0.040189           NaN          16       0.15
# 65  0.570522      0.037998           NaN          16       0.15
# 66  0.525619      0.023270      densenet          16       0.15
# 67  0.519238      0.030662      densenet          16       0.15
#
#     early_stopping_patience  foldlabel       input_size      lr  max_angle  \
# 0                       100      False  (1, 22, 46, 38)  0.0004         10
# 1                       100      False  (1, 17, 40, 38)  0.0004         10
# 2                       100       True  (1, 22, 46, 38)  0.0004          6
# 3                       100      False  (1, 22, 46, 38)  0.0004         10
# 4                       100      False  (1, 17, 40, 38)  0.0004         10
# ..                      ...        ...              ...     ...        ...
# 63                      100      False  (1, 17, 40, 38)  0.0004         10
# 64                      250      False  (1, 17, 40, 38)  0.0004         10
# 65                      100      False  (1, 17, 40, 38)  0.0004         10
# 66                      100      False  (1, 17, 40, 38)  0.0004         10
# 67                      100      False  (1, 17, 40, 38)  0.0004         10
#
#     max_epochs  num_outputs  num_representation_features  \
# 0          250           30                           30
# 1          250           30                           30
# 2          250           30                           30
# 3          250            4                            4
# 4          250           30                           30
# ..         ...          ...                          ...
# 63          20           30                           12
# 64         300           30                           30
# 65         250           30                           30
# 66         250           30                           30
# 67         250           30                           30
#
#                                             numpy_all  temperature  \
# 0   /neurospin/dico/data/deep_folding/current/data...          0.1
# 1   /neurospin/dico/data/deep_folding/current/data...          0.1
# 2   /neurospin/dico/data/deep_folding/current/data...          0.1
# 3   /neurospin/dico/data/deep_folding/current/data...          0.1
# 4   /neurospin/dico/data/deep_folding/current/data...          0.1
# ..                                                ...          ...
# 63  /neurospin/dico/data/deep_folding/current/data...          0.5
# 64  /neurospin/dico/data/deep_folding/current/data...          0.1
# 65  /neurospin/dico/data/deep_folding/current/data...          0.1
# 66  /neurospin/dico/data/deep_folding/current/data...          0.5
# 67  /neurospin/dico/data/deep_folding/current/data...          0.5
#
#     temperature_initial      git_branch
# 0                   0.1  Run_03_aymeric
# 1                   0.1  Run_03_aymeric
# 2                   0.1  Run_03_aymeric
# 3                   0.1  Run_03_aymeric
# 4                   0.1  Run_03_aymeric
# ..                  ...             ...
# 63                  0.5  Run_03_aymeric
# 64                  0.1     Run_43_joel
# 65                  0.1     Run_43_joel
# 66                  0.5  Run_03_aymeric
# 67                  0.5  Run_03_aymeric
#
# [68 rows x 20 columns]

# %%
save_path = "/neurospin/dico/agaudin/Runs/bdd_models.csv"
bdd_models.to_csv(save_path, index=True)

# %%
bdd_models['git_branch'] = 'Run_03_aymeric'
bdd_models.columns
# Out:
# Index(['model_path', 'auc', 'auc_std', 'accuracy', 'accuracy_std',
#        'backbone_name', 'batch_size', 'checkerboard_size', 'depth_decoder',
#        'drop_rate', 'early_stopping_patience', 'environment', 'fill_value',
#        'foldlabel', 'input_size', 'keep_bottom', 'lr', 'max_angle',
#        'max_epochs', 'mode', 'model', 'nb_subjects', 'num_outputs',
#        'num_representation_features', 'numpy_all', 'partition', 'patch_size',
#        'pin_mem', 'seed', 'sigma', 'temperature', 'temperature_initial',
#        'train_val_csv_file', 'weight_decay', 'with_labels', 'block_config',
#        'growth_rate', 'num_init_features', 'git_branch'],
#       dtype='object')
