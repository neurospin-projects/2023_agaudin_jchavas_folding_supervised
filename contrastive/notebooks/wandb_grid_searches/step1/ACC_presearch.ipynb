# %%
import numpy as np
import pandas as pd
pd.set_option("display.max_rows", 20)
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def graphs(bdd, param, continuous=False, min_param=0, max_param=1, log=False):
    if continuous:
        if log:
            bdd[f'{param}_interval'] = pd.cut(bdd[param], np.logspace(min_param, max_param, 21))
        else:
            bdd[f'{param}_interval'] = pd.cut(bdd[param], np.linspace(min_param, max_param, 21))

    plt.figure(figsize=(16,12))

    plt.subplot(221)
    sns.scatterplot(bdd, x=param, y='best_val_auc')
    if log:
        plt.xscale('log')

    plt.subplot(223)
    if continuous:
        x = f'{param}_interval'
    else:
        x = param
    sns.barplot(bdd, x=x, y='best_val_auc')
    plt.xticks(rotation=90)

    plt.subplot(222)
    sns.scatterplot(bdd, x=param, y='best_test_auc')
    if log:
        plt.xscale('log')

    plt.subplot(224)
    sns.barplot(bdd, x=x, y='best_test_auc')
    plt.xticks(rotation=90)

    plt.show()

# %%
def graphs_intra(bdd, param, continuous=False, min_param=0, max_param=1, log=False):
    if continuous:
        if log:
            bdd[f'{param}_interval'] = pd.cut(bdd[param], np.logspace(min_param, max_param, 21))
        else:
            bdd[f'{param}_interval'] = pd.cut(bdd[param], np.linspace(min_param, max_param, 21))
    plt.figure(figsize=(24,12))

    plt.subplot(231)
    sns.scatterplot(bdd, x=param, y='best_val_auc')
    if log:
        plt.xscale('log')

    plt.subplot(234)
    if continuous:
        x = f'{param}_interval'
    else:
        x = param
    sns.barplot(bdd, x=x, y='best_val_auc')
    plt.xticks(rotation=90)


    plt.subplot(232)
    sns.scatterplot(bdd, x=param, y='best_test_intra_auc')
    if log:
        plt.xscale('log')

    plt.subplot(235)
    sns.barplot(bdd, x=x, y='best_test_intra_auc')
    plt.xticks(rotation=90)


    plt.subplot(233)
    sns.scatterplot(bdd, x=param, y='best_test_auc')
    if log:
        plt.xscale('log')

    plt.subplot(236)
    sns.barplot(bdd, x=x, y='best_test_auc')
    plt.xticks(rotation=90)

    plt.show()

# %% [markdown]
# # PCS asymetry (incomplete grid search)

# %%
bdd_asymetry = pd.read_csv("/neurospin/dico/agaudin/Runs/09_new_repo/Output/grid_searches/grid_search_0/bdd_ACC_asymetry.csv", index_col=0)
bdd_asymetry = bdd_asymetry.sort_values(by='best_val_auc', ascending=False)
bdd_asymetry[:20]
# Out:
#                                            model_path  train_auc   val_auc  \
# 38  /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.587122  0.368132
# 48  /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.597312  0.346154
# 45  /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.647660  0.445055
# 55  /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.725788  0.445055
# 19  /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.621507  0.401099
# 34  /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.618818  0.395604
# 4   /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.583870  0.409341
# 40  /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.601925  0.387363
# 52  /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.623365  0.390110
# 23  /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.704879  0.560440
# 36  /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.624361  0.406593
# 21  /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.395420  0.510989
# 28  /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.687654  0.516484
# 31  /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.601162  0.516484
# 7   /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.671623  0.521978
# 42  /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.599734  0.395604
# 18  /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.629605  0.395604
# 17  /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.665118  0.516484
# 44  /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.607036  0.373626
# 37  /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.997212  0.565934
#
#     test_auc  best_train_auc  best_val_auc  best_test_auc  \
# 38  0.527679        0.564321      0.769231       0.583036
# 48  0.536607        0.448258      0.763736       0.446875
# 45  0.535714        0.663923      0.747253       0.533036
# 55  0.552679        0.671092      0.741758       0.550000
# 19  0.580357        0.382078      0.730769       0.377679
# 34  0.557143        0.538201      0.725275       0.555804
# 4   0.547768        0.512612      0.725275       0.434821
# 40  0.570089        0.605377      0.725275       0.544643
# 52  0.559821        0.491636      0.714286       0.500000
# 23  0.596429        0.606173      0.708791       0.500000
# 36  0.585714        0.553004      0.708791       0.581250
# 21  0.393750        0.450481      0.703297       0.569643
# 28  0.503571        0.597013      0.700549       0.570089
# 31  0.556250        0.424925      0.695055       0.512500
# 7   0.633929        0.665848      0.692308       0.685714
# 42  0.575893        0.435314      0.686813       0.357589
# 18  0.569643        0.424029      0.686813       0.446429
# 17  0.504464        0.766313      0.681319       0.482143
# 44  0.519196        0.427912      0.675824       0.537946
# 37  0.458036        0.960040      0.670330       0.485714
#
#     backbone_output_size converter_activation  drop_rate  \
# 38                     6               linear   0.101641
# 48                    25              sigmoid   0.003547
# 45                     7               linear   0.124574
# 55                    32               linear   0.054651
# 19                    13               linear   0.170533
# 34                    12              sigmoid   0.044510
# 4                     17               linear   0.018068
# 40                     7               linear   0.079906
# 52                    20                 relu   0.167950
# 23                    15               linear   0.036648
# 36                     9               linear   0.052751
# 21                    21               linear   0.099753
# 28                    30              sigmoid   0.099786
# 31                     8              sigmoid   0.032367
# 7                     14               linear   0.054877
# 42                    21                 relu   0.083930
# 18                    21                 relu   0.031968
# 17                     7                 relu   0.129236
# 44                    32              sigmoid   0.196729
# 37                    30                 relu   0.023703
#
#     fusioned_latent_space_size        lr  max_angle projection_head_name  \
# 38                          27  0.005235          4                 relu
# 48                          18  0.009063          2              sigmoid
# 45                          14  0.000900          6                 relu
# 55                          27  0.002312          6               linear
# 19                          25  0.007907          5                 relu
# 34                          18  0.002521          3                 relu
# 4                           21  0.008230          3              sigmoid
# 40                          11  0.004812          3              sigmoid
# 52                           6  0.004121          6              sigmoid
# 23                          21  0.003842          4               linear
# 36                          31  0.008713          3               linear
# 21                          20  0.002024          0              sigmoid
# 28                          27  0.000355          4                 relu
# 31                          20  0.008678          1                 relu
# 7                           21  0.006404          4               linear
# 42                          22  0.001714          3              sigmoid
# 18                          21  0.001825          4               linear
# 17                          20  0.000531          0              sigmoid
# 44                           4  0.004810          6               linear
# 37                          30  0.000110          1               linear
#
#     sigma_noise  train_loss
# 38     0.034942    1.381315
# 48     0.098650    1.381988
# 45     0.033183    1.366361
# 55     0.474892    1.309247
# 19     0.014232    1.379737
# 34     0.097224    1.376534
# 4      0.053203    1.385013
# 40     0.068738    1.378492
# 52     0.237346    1.379801
# 23     0.305876    1.343533
# 36     0.379796    1.378052
# 21     0.455144    1.382160
# 28     0.309614    1.385988
# 31     0.446917    1.384924
# 7      0.212866    1.378679
# 42     0.344272    1.373518
# 18     0.430995    1.387263
# 17     0.239039    1.378844
# 44     0.263690    1.380958
# 37     0.255310    0.948849

# %%
bdd_asymetry = bdd_asymetry.sort_values(by='best_test_auc', ascending=False)
bdd_asymetry[:20]
# Out:
#                                            model_path  train_auc   val_auc  \
# 7   /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.671623  0.521978
# 32  /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.499967  0.560440
# 0   /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.729937  0.510989
# 47  /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.552705  0.296703
# 56  /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.606704  0.423077
# 38  /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.587122  0.368132
# 36  /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.624361  0.406593
# 16  /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.456920  0.609890
# 28  /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.687654  0.516484
# 21  /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.395420  0.510989
# 54  /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.619748  0.390110
# 34  /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.618818  0.395604
# 15  /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.630202  0.447802
# 6   /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.612778  0.401099
# 55  /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.725788  0.445055
# 1   /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.476104  0.571429
# 40  /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.601925  0.387363
# 35  /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.632127  0.428571
# 44  /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.607036  0.373626
# 9   /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.485496  0.587912
#
#     test_auc  best_train_auc  best_val_auc  best_test_auc  \
# 7   0.633929        0.665848      0.692308       0.685714
# 32  0.396429        0.558214      0.642857       0.649107
# 0   0.544643        0.741819      0.626374       0.604018
# 47  0.527679        0.525456      0.653846       0.593750
# 56  0.566964        0.468968      0.587912       0.583036
# 38  0.527679        0.564321      0.769231       0.583036
# 36  0.585714        0.553004      0.708791       0.581250
# 16  0.577679        0.470063      0.607143       0.576339
# 28  0.503571        0.597013      0.700549       0.570089
# 21  0.393750        0.450481      0.703297       0.569643
# 54  0.568750        0.457982      0.670330       0.567857
# 34  0.557143        0.538201      0.725275       0.555804
# 15  0.581696        0.462264      0.634615       0.552679
# 6   0.575000        0.465151      0.598901       0.552679
# 55  0.552679        0.671092      0.741758       0.550000
# 1   0.520982        0.533555      0.609890       0.545536
# 40  0.570089        0.605377      0.725275       0.544643
# 35  0.593750        0.447195      0.653846       0.538393
# 44  0.519196        0.427912      0.675824       0.537946
# 9   0.552679        0.518752      0.670330       0.534821
#
#     backbone_output_size converter_activation  drop_rate  \
# 7                     14               linear   0.054877
# 32                     5               linear   0.100800
# 0                     21                 relu   0.181952
# 47                     8               linear   0.084462
# 56                    15                 relu   0.138885
# 38                     6               linear   0.101641
# 36                     9               linear   0.052751
# 16                    29              sigmoid   0.072057
# 28                    30              sigmoid   0.099786
# 21                    21               linear   0.099753
# 54                    32                 relu   0.109611
# 34                    12              sigmoid   0.044510
# 15                     4                 relu   0.029044
# 6                     11              sigmoid   0.181391
# 55                    32               linear   0.054651
# 1                     27                 relu   0.089092
# 40                     7               linear   0.079906
# 35                    15               linear   0.177136
# 44                    32              sigmoid   0.196729
# 9                     21                 relu   0.130366
#
#     fusioned_latent_space_size        lr  max_angle projection_head_name  \
# 7                           21  0.006404          4               linear
# 32                          29  0.002299          0                 relu
# 0                           12  0.000495          0               linear
# 47                           6  0.002177          2              sigmoid
# 56                          30  0.006831          4               linear
# 38                          27  0.005235          4                 relu
# 36                          31  0.008713          3               linear
# 16                          10  0.009419          1              sigmoid
# 28                          27  0.000355          4                 relu
# 21                          20  0.002024          0              sigmoid
# 54                          11  0.002495          3              sigmoid
# 34                          18  0.002521          3                 relu
# 15                          16  0.008555          1              sigmoid
# 6                           12  0.002384          0                 relu
# 55                          27  0.002312          6               linear
# 1                           26  0.006928          1               linear
# 40                          11  0.004812          3              sigmoid
# 35                          20  0.007000          3               linear
# 44                           4  0.004810          6               linear
# 9                           29  0.005215          6              sigmoid
#
#     sigma_noise  train_loss
# 7      0.212866    1.378679
# 32     0.020888    1.382980
# 0      0.181714    1.363711
# 47     0.293169    1.371022
# 56     0.355646    1.381356
# 38     0.034942    1.381315
# 36     0.379796    1.378052
# 16     0.371465    1.383948
# 28     0.309614    1.385988
# 21     0.455144    1.382160
# 54     0.111890    1.384521
# 34     0.097224    1.376534
# 15     0.462236    1.379416
# 6      0.320771    1.385277
# 55     0.474892    1.309247
# 1      0.251681    1.386644
# 40     0.068738    1.378492
# 35     0.154855    1.377609
# 44     0.263690    1.380958
# 9      0.210134    1.383839

# %% [markdown]
# ## Supervised parameters

# %% [markdown]
# ### drop rate

# %%
graphs(bdd_asymetry, 'drop_rate', continuous=True,
       min_param=0, max_param=0.2)

# %% [markdown]
# ### sigma noise

# %%
graphs(bdd_asymetry, 'sigma_noise', continuous=True,
       min_param=0, max_param=0.5)

# %% [markdown]
# ### lr

# %%
graphs(bdd_asymetry, 'lr', continuous=True,
       min_param=0, max_param=0.01)

# %% [markdown]
# ### Max angle

# %%
graphs(bdd_asymetry, 'max_angle', continuous=False,
       min_param=0, max_param=0.01)

# %% [markdown]
# ## Structure parameters

# %% [markdown]
# ### Projection head activation

# %%
bdd_asymetry = bdd_asymetry.sort_values(['projection_head_name'])
graphs(bdd_asymetry, 'projection_head_name', continuous=False,
       min_param=0, max_param=0.5)

# %% [markdown]
# ### Converter activation

# %%
bdd_asymetry = bdd_asymetry.sort_values(['converter_activation', 'projection_head_name'])

graphs(bdd_asymetry, 'converter_activation', continuous=False,
       min_param=0, max_param=0.5)


plt.figure(figsize=(16,6))
plt.subplot(121)
sns.barplot(bdd_asymetry, x='converter_activation', y='best_val_auc', hue='projection_head_name')

plt.subplot(122)
sns.barplot(bdd_asymetry, x='converter_activation', y='best_test_auc', hue='projection_head_name')
# Out:
# <Axes: xlabel='converter_activation', ylabel='best_test_auc'>

# %% [markdown]
# ### Latent space size

# %%
graphs(bdd_asymetry, 'fusioned_latent_space_size', continuous=False,
       min_param=0, max_param=0.5)

# %% [markdown]
# ### Encoder output size

# %%
graphs(bdd_asymetry, 'backbone_output_size', continuous=False,
       min_param=0, max_param=0.5)

# %% [markdown]
# # True PCS asymetry grid search

# %%
bdd_asymetry_2 = pd.read_csv("/neurospin/dico/agaudin/Runs/09_new_repo/Output/grid_searches/grid_search_ACC_asymetry/bdd_ACC_asymetry.csv", index_col=0)
bdd_asymetry_2 = bdd_asymetry_2.sort_values(by='best_test_auc', ascending=False)
bdd_asymetry_2.loc[bdd_asymetry_2.fusioned_latent_space_size == -1, 'converter_activation'] = 'None'
bdd_asymetry_2[:20]
# Out:
#                                             model_path  train_auc   val_auc  \
# 55   /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.427415  0.552198
# 30   /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.621905  0.500000
# 104  /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.500000  0.500000
# 14   /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.417922  0.510989
# 43   /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.608596  0.450549
# 100  /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.621640  0.406593
# 21   /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.596349  0.384615
# 81   /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.587720  0.461538
# 28   /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.616263  0.494505
# 71   /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.475274  0.483516
# 10   /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.989114  0.538462
# 18   /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.498075  0.329670
# 99   /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.429174  0.604396
# 69   /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.981679  0.472527
# 124  /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.594391  0.392857
# 23   /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.618387  0.439560
# 74   /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.564487  0.414835
# 67   /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   1.000000  0.505495
# 51   /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.621440  0.439560
# 37   /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.580816  0.412088
#
#      test_auc  best_train_auc  best_val_auc  best_test_auc  \
# 55   0.516518        0.490840      0.631868       0.642857
# 30   0.545536        0.595188      0.576923       0.621429
# 104  0.500000        0.559144      0.604396       0.616071
# 14   0.541071        0.544076      0.697802       0.600446
# 43   0.563393        0.489147      0.571429       0.596429
# 100  0.574107        0.533322      0.631868       0.591964
# 21   0.580357        0.553933      0.840659       0.590179
# 81   0.583036        0.515765      0.598901       0.589286
# 28   0.573214        0.448291      0.708791       0.588393
# 71   0.418750        0.601328      0.640110       0.587054
# 10   0.510714        0.826552      0.620879       0.586607
# 18   0.573214        0.537604      0.642857       0.583036
# 99   0.541964        0.467342      0.626374       0.578571
# 69   0.490179        0.829472      0.532967       0.578571
# 124  0.425446        0.473415      0.634615       0.577232
# 23   0.595536        0.546167      0.664835       0.575893
# 74   0.589286        0.561898      0.631868       0.573661
# 67   0.592857        0.846996      0.719780       0.573214
# 51   0.581250        0.501095      0.527473       0.570536
# 37   0.564286        0.493594      0.664835       0.555804
#
#      backbone_output_size converter_activation  drop_rate  \
# 55                     32              sigmoid   0.121993
# 30                     32                 relu   0.164186
# 104                    32                 None   0.093346
# 14                     32               linear   0.158480
# 43                     32                 None   0.159268
# 100                    32              sigmoid   0.124792
# 21                     32                 None   0.103402
# 81                     32              sigmoid   0.157120
# 28                     32                 None   0.105552
# 71                     32                 None   0.128706
# 10                     10                 None   0.074229
# 18                     32                 None   0.048979
# 99                     32              sigmoid   0.169660
# 69                     10                 None   0.007747
# 124                    32               linear   0.105504
# 23                     32                 None   0.110845
# 74                     32                 relu   0.121089
# 67                      4                 None   0.161224
# 51                     32                 relu   0.170388
# 37                     32                 None   0.100188
#
#      fusioned_latent_space_size        lr  max_angle projection_head_name  \
# 55                           10  0.007787          4              sigmoid
# 30                           10  0.001588          5              sigmoid
# 104                          -1  0.009456          4              sigmoid
# 14                           10  0.005212          3              sigmoid
# 43                           -1  0.002332          6              sigmoid
# 100                          32  0.001698          2              sigmoid
# 21                           -1  0.003820          6              sigmoid
# 81                           10  0.001872          4              sigmoid
# 28                           -1  0.006751          5              sigmoid
# 71                           -1  0.006427          5              sigmoid
# 10                           -1  0.000446          2               linear
# 18                           -1  0.009278          6              sigmoid
# 99                            4  0.003654          5              sigmoid
# 69                           -1  0.000416          1                 relu
# 124                           4  0.005393          6              sigmoid
# 23                           -1  0.008908          4                 relu
# 74                            4  0.003054          5              sigmoid
# 67                           -1  0.000545          6               linear
# 51                            4  0.004037          6              sigmoid
# 37                           -1  0.003263          5              sigmoid
#
#      sigma_noise  train_loss
# 55      0.155977    1.382976
# 30      0.090636    1.382362
# 104     0.166811    1.383128
# 14      0.077259    1.386484
# 43      0.246319    1.383916
# 100     0.184186    1.378527
# 21      0.453541    1.383730
# 81      0.076643    1.377136
# 28      0.266087    1.386663
# 71      0.074562    1.396636
# 10      0.422082    1.076396
# 18      0.481230    1.399353
# 99      0.308099    1.380745
# 69      0.373324    1.285253
# 124     0.296176    1.384833
# 23      0.316288    1.386177
# 74      0.114087    1.380715
# 67      0.032383    0.606093
# 51      0.249489    1.383360
# 37      0.229721    1.394090

# %% [markdown]
# ## Supervised parameters

# %% [markdown]
# ### Drop rate

# %%
graphs(bdd_asymetry_2, 'drop_rate', continuous=True,
       min_param=0, max_param=0.2)

# %% [markdown]
# ### Sigma noise

# %%
graphs(bdd_asymetry_2, 'sigma_noise', continuous=True,
       min_param=0, max_param=0.5)

# %% [markdown]
# ### Learning rate

# %%
graphs(bdd_asymetry_2, 'lr', continuous=True,
       min_param=0, max_param=0.01)

# %% [markdown]
# ### Max angle

# %%
graphs(bdd_asymetry_2, 'max_angle', continuous=False,
       min_param=0, max_param=0.01)

# %% [markdown]
# ## Structure parameters

# %% [markdown]
# ### Projection head activation

# %%
bdd_asymetry_2 = bdd_asymetry_2.sort_values(['projection_head_name'])
graphs(bdd_asymetry_2, 'projection_head_name', continuous=False,
       min_param=0, max_param=0.2)

# %% [markdown]
# ### Converter activation

# %%
bdd_asymetry_2 = bdd_asymetry_2.sort_values(['converter_activation', 'projection_head_name'])
graphs(bdd_asymetry_2, 'converter_activation', continuous=False,
       min_param=0, max_param=0.2)

plt.figure(figsize=(16,6))
plt.subplot(121)
sns.barplot(bdd_asymetry_2, x='converter_activation', y='best_val_auc', hue='projection_head_name')

plt.subplot(122)
sns.barplot(bdd_asymetry_2, x='converter_activation', y='best_test_auc', hue='projection_head_name')
# Out:
# <Axes: xlabel='converter_activation', ylabel='best_test_auc'>

# %% [markdown]
# ### Backbone output size

# %%
graphs(bdd_asymetry_2, 'backbone_output_size', continuous=False,
       min_param=0, max_param=0.2)

# %% [markdown]
# ### Fusioned latent space size

# %%
graphs(bdd_asymetry_2, 'fusioned_latent_space_size', continuous=False,
       min_param=0, max_param=0.2)

# %% [markdown]
# # Cing schiz

# %%
bdd_schiz = pd.read_csv("/neurospin/dico/agaudin/Runs/09_new_repo/Output/grid_searches/gs_cing_schiz/bdd_cing_schiz.csv", index_col=0)
bdd_schiz = bdd_schiz.sort_values(by='best_test_auc', ascending=False)
bdd_schiz.loc[bdd_schiz.fusioned_latent_space_size == -1, 'converter_activation'] = 'None'
bdd_schiz[:20]
# Out:
#                                             model_path  train_auc   val_auc  \
# 62   /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.500000  0.500000
# 64   /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.499093  0.500000
# 121  /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.651688  0.553846
# 122  /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.605624  0.619543
# 110  /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.550975  0.556341
# 136  /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.540401  0.562994
# 14   /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.416094  0.413514
# 126  /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.584753  0.546362
# 43   /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.935073  0.511642
# 67   /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.562157  0.516008
# 40   /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.582723  0.590437
# 21   /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.609098  0.592516
# 91   /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.585713  0.545530
# 109  /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.608221  0.600832
# 116  /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.612823  0.595842
# 87   /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.601541  0.590021
# 73   /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.607980  0.606653
# 140  /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.968024  0.525988
# 83   /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.500000  0.500000
# 86   /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.575395  0.543867
#
#      test_auc  test_intra_auc  best_train_auc  best_val_auc  best_test_auc  \
# 62   0.500000        0.500000        0.589578      0.517048       0.626321
# 64   0.500000        0.500000        0.592968      0.594595       0.624962
# 121  0.542887        0.620382        0.599758      0.646985       0.619903
# 122  0.610541        0.614532        0.602426      0.608732       0.616883
# 110  0.551722        0.550493        0.596500      0.604990       0.615071
# 136  0.613259        0.528787        0.600470      0.609563       0.614844
# 14   0.459604        0.406404        0.592043      0.607692       0.614769
# 126  0.555270        0.612069        0.600062      0.598753       0.614618
# 43   0.555648        0.596675        0.666922      0.645738       0.612655
# 67   0.547946        0.618534        0.592619      0.578794       0.610616
# 40   0.606690        0.594982        0.607805      0.645738       0.610314
# 21   0.600121        0.612993        0.612387      0.612474       0.609484
# 91   0.572486        0.612685        0.596264      0.593347       0.609182
# 109  0.602084        0.612069        0.601242      0.603742       0.608426
# 116  0.606765        0.609298        0.608001      0.607069       0.608124
# 87   0.600347        0.614224        0.586438      0.598960       0.606010
# 73   0.592872        0.612685        0.611219      0.612058       0.604349
# 140  0.590456        0.601909        0.648472      0.613306       0.603594
# 83   0.500000        0.500000        0.564401      0.525364       0.603594
# 86   0.502492        0.604680        0.594717      0.619127       0.603443
#
#      best_test_intra_auc  backbone_output_size converter_activation  \
# 62              0.564347                    32              sigmoid
# 64              0.611453                    10              sigmoid
# 121             0.599138                    32               linear
# 122             0.603448                    32                 relu
# 110             0.596983                    32               linear
# 136             0.616071                    32                 relu
# 14              0.607451                    32                 relu
# 126             0.606527                    32                 relu
# 43              0.593596                    10               linear
# 67              0.598830                    32              sigmoid
# 40              0.631158                    32              sigmoid
# 21              0.609298                    32                 relu
# 91              0.605296                    10                 relu
# 109             0.601909                    32                 relu
# 116             0.607759                    32               linear
# 87              0.649938                    32                 relu
# 73              0.614532                    10                 relu
# 140             0.596675                     4                 relu
# 83              0.570813                    32                 relu
# 86              0.614378                    32                 relu
#
#      drop_rate  fusioned_latent_space_size        lr  max_angle  \
# 62    0.118947                          32  0.033255          5
# 64    0.127293                          10  0.050001          3
# 121   0.120716                          10  0.004673          3
# 122   0.148264                           4  0.000465          5
# 110   0.143790                          10  0.016832          2
# 136   0.103074                          10  0.012070          4
# 14    0.068104                          10  0.022089          6
# 126   0.109170                          32  0.002224          4
# 43    0.002065                          10  0.000780          0
# 67    0.049819                          32  0.024818          5
# 40    0.109104                          32  0.019150          4
# 21    0.084080                          32  0.021529          5
# 91    0.112305                          10  0.004880          4
# 109   0.110289                           4  0.003049          4
# 116   0.190994                           4  0.000933          6
# 87    0.139310                          10  0.001096          3
# 73    0.093414                          10  0.019246          4
# 140   0.116883                          10  0.000461          0
# 83    0.114045                          32  0.029785          3
# 86    0.149670                          10  0.003393          3
#
#     projection_head_name  sigma_noise  train_loss
# 62                  relu     0.079131    1.342983
# 64                  relu     0.177161    1.338679
# 121                 relu     0.241553    1.324623
# 122              sigmoid     0.167260    1.336136
# 110                 relu     0.230088    1.348551
# 136              sigmoid     0.197504    1.353640
# 14               sigmoid     0.231997    1.338101
# 126              sigmoid     0.300322    1.352389
# 43               sigmoid     0.457755    1.018704
# 67               sigmoid     0.049217    1.339042
# 40               sigmoid     0.137574    1.340570
# 21                  relu     0.110795    1.340949
# 91               sigmoid     0.228313    1.355118
# 109              sigmoid     0.198917    1.345450
# 116              sigmoid     0.099180    1.334629
# 87               sigmoid     0.236538    1.337167
# 73                  relu     0.210997    1.340494
# 140                 relu     0.197987    0.919949
# 83               sigmoid     0.156082    1.347343
# 86               sigmoid     0.105899    1.327285

# %% [markdown]
# ## Supervised parameters

# %% [markdown]
# ### Drop rate

# %%
graphs_intra(bdd_schiz, 'drop_rate', continuous=True,
             min_param=0, max_param=0.2)

# %% [markdown]
# ### Sigma noise

# %%
graphs_intra(bdd_schiz, 'sigma_noise', continuous=True,
             min_param=0, max_param=0.5)

# %% [markdown]
# ### Learning rate

# %%
graphs_intra(bdd_schiz, 'lr', continuous=True,
             min_param=-4, max_param=-1, log=True)

# %% [markdown]
# ### Max angle

# %%
graphs_intra(bdd_schiz, 'max_angle', continuous=False,
             min_param=0, max_param=0.5)

# %% [markdown]
# ## Structure parameters

# %% [markdown]
# ### Projection head activation

# %%
bdd_schiz = bdd_schiz.sort_values(['projection_head_name'])
graphs_intra(bdd_schiz, 'projection_head_name', continuous=False,
             min_param=0, max_param=0.2)

# %% [markdown]
# ### Converter activation

# %%
bdd_schiz = bdd_schiz.sort_values(['converter_activation', 'projection_head_name'])
graphs_intra(bdd_schiz, 'converter_activation', continuous=False,
             min_param=0, max_param=0.2)

plt.figure(figsize=(24,6))
plt.subplot(131)
sns.barplot(bdd_schiz, x='converter_activation', y='best_val_auc', hue='projection_head_name')

plt.subplot(132)
sns.barplot(bdd_schiz, x='converter_activation', y='best_test_intra_auc', hue='projection_head_name')

plt.subplot(133)
sns.barplot(bdd_schiz, x='converter_activation', y='best_test_auc', hue='projection_head_name')
# Out:
# <Axes: xlabel='converter_activation', ylabel='best_test_auc'>

# %% [markdown]
# ### Backbone output size

# %%
graphs_intra(bdd_schiz, 'backbone_output_size', continuous=False,
             min_param=0, max_param=0.2)

# %% [markdown]
# ### Fusioned latent space size

# %%
graphs_intra(bdd_schiz, 'fusioned_latent_space_size', continuous=False,
             min_param=0, max_param=0.2)

# %% [markdown]
# # Activation further comparison (just more models for some conditions)

# %%
bdd_activations = pd.read_csv("/neurospin/dico/agaudin/Runs/09_new_repo/Output/grid_searches/step1/bdd_activations.csv", index_col=0)
bdd_activations
# Out:
#                                            model_path  train_auc   val_auc  \
# 0   /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.774293  0.649480
# 1   /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.598395  0.621206
# 2   /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.903596  0.580042
# 3   /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.995774  0.567983
# 4   /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.608111  0.610811
# ..                                                ...        ...       ...
# 22  /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.903598  0.541996
# 23  /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.663487  0.563825
# 24  /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.479412  0.543451
# 25  /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.874530  0.613721
# 26  /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.575591  0.610187
#
#     test_auc  test_intra_auc  best_train_auc  best_val_auc  best_test_auc  \
# 0   0.494111        0.488300        0.725923      0.668191       0.514950
# 1   0.588644        0.600369        0.611134      0.621206       0.599064
# 2   0.496225        0.531404        0.709408      0.631185       0.509816
# 3   0.565690        0.550185        0.688377      0.594595       0.563576
# 4   0.600423        0.624384        0.529234      0.632432       0.540622
# ..       ...             ...             ...           ...            ...
# 22  0.525445        0.562192        0.698885      0.670270       0.514044
# 23  0.622471        0.632389        0.614145      0.610811       0.606614
# 24  0.427061        0.441195        0.603629      0.602911       0.606841
# 25  0.540169        0.519397        0.723431      0.631185       0.551042
# 26  0.560405        0.567272        0.599961      0.676923       0.532468
#
#     best_test_intra_auc  drop_rate  fusioned_latent_space_size        lr  \
# 0              0.565579   0.072939                          10  0.000840
# 1              0.611761   0.099463                          10  0.013183
# 2              0.580049   0.147964                          10  0.000381
# 3              0.619150   0.055323                          10  0.000229
# 4              0.418719   0.100606                          10  0.018595
# ..                  ...        ...                         ...       ...
# 22             0.568658   0.054652                          -1  0.001431
# 23             0.609298   0.062589                          -1  0.002203
# 24             0.622845   0.093933                          -1  0.011720
# 25             0.504618   0.068390                          -1  0.004813
# 26             0.576663   0.142079                          -1  0.006037
#
#     max_angle projection_head_name  sigma_noise  train_loss
# 0           6                 relu     0.295341    1.268184
# 1           6                 relu     0.007683    1.370179
# 2           4                 relu     0.189182    1.060053
# 3           3                 relu     0.038142    0.927314
# 4           6                 relu     0.015524    1.355021
# ..        ...                  ...          ...         ...
# 22          0              sigmoid     0.062278    0.974331
# 23          0              sigmoid     0.003262    1.305248
# 24          0              sigmoid     0.043766    1.364846
# 25          0              sigmoid     0.076198    1.007713
# 26          1              sigmoid     0.202483    1.353748
#
# [27 rows x 16 columns]

# %%
relu_relu = bdd_activations[bdd_activations.projection_head_name == 'relu']
relu_relu
# Out:
#                                            model_path  train_auc   val_auc  \
# 0   /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.774293  0.649480
# 1   /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.598395  0.621206
# 2   /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.903596  0.580042
# 3   /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.995774  0.567983
# 4   /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.608111  0.610811
# 5   /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.699306  0.612474
# 6   /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.607048  0.595842
# 7   /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.602571  0.595842
# 8   /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.639545  0.614553
# 9   /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.676786  0.659459
# 10  /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.603960  0.596674
# 11  /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.677417  0.584615
# 12  /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.775110  0.685239
#
#     test_auc  test_intra_auc  best_train_auc  best_val_auc  best_test_auc  \
# 0   0.494111        0.488300        0.725923      0.668191       0.514950
# 1   0.588644        0.600369        0.611134      0.621206       0.599064
# 2   0.496225        0.531404        0.709408      0.631185       0.509816
# 3   0.565690        0.550185        0.688377      0.594595       0.563576
# 4   0.600423        0.624384        0.529234      0.632432       0.540622
# 5   0.516762        0.560037        0.719701      0.662786       0.563576
# 6   0.604047        0.614840        0.607309      0.644906       0.590909
# 7   0.626397        0.593596        0.601122      0.608732       0.591664
# 8   0.504983        0.612685        0.631897      0.665696       0.551948
# 9   0.540169        0.626847        0.658155      0.662786       0.529447
# 10  0.603745        0.605296        0.594630      0.596258       0.625189
# 11  0.495319        0.581589        0.646695      0.654470       0.570371
# 12  0.602537        0.612993        0.770493      0.691060       0.602084
#
#     best_test_intra_auc  drop_rate  fusioned_latent_space_size        lr  \
# 0              0.565579   0.072939                          10  0.000840
# 1              0.611761   0.099463                          10  0.013183
# 2              0.580049   0.147964                          10  0.000381
# 3              0.619150   0.055323                          10  0.000229
# 4              0.418719   0.100606                          10  0.018595
# 5              0.618842   0.074697                          10  0.001234
# 6              0.599138   0.048827                          10  0.029429
# 7              0.599754   0.112097                          10  0.020786
# 8              0.602525   0.102229                          10  0.001890
# 9              0.618842   0.055359                          10  0.001224
# 10             0.610222   0.104516                          10  0.004775
# 11             0.625308   0.111851                          10  0.002408
# 12             0.616071   0.046028                          10  0.001778
#
#     max_angle projection_head_name  sigma_noise  train_loss drop_rate_interval
# 0           6                 relu     0.295341    1.268184       (0.07, 0.08]
# 1           6                 relu     0.007683    1.370179        (0.09, 0.1]
# 2           4                 relu     0.189182    1.060053       (0.14, 0.15]
# 3           3                 relu     0.038142    0.927314       (0.05, 0.06]
# 4           6                 relu     0.015524    1.355021        (0.1, 0.11]
# 5           6                 relu     0.260366    1.279598       (0.07, 0.08]
# 6           6                 relu     0.256758    1.338148       (0.04, 0.05]
# 7           6                 relu     0.284872    1.342063       (0.11, 0.12]
# 8           6                 relu     0.275675    1.333295        (0.1, 0.11]
# 9           6                 relu     0.310296    1.307623       (0.05, 0.06]
# 10          6                 relu     0.286782    1.348089        (0.1, 0.11]
# 11          6                 relu     0.437719    1.315664       (0.11, 0.12]
# 12          6                 relu     0.345265    1.246554       (0.04, 0.05]

# %%
none_sigmoid = bdd_activations[bdd_activations.projection_head_name == 'sigmoid']
none_sigmoid
# Out:
#                                            model_path  train_auc   val_auc  \
# 13  /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.625620  0.565904
# 14  /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.971576  0.556341
# 15  /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.939547  0.505405
# 16  /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.605892  0.477131
# 17  /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.580740  0.511227
# 18  /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.631940  0.549272
# 19  /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.452863  0.496466
# 20  /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.603027  0.614969
# 21  /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.814248  0.508108
# 22  /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.903598  0.541996
# 23  /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.663487  0.563825
# 24  /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.479412  0.543451
# 25  /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.874530  0.613721
# 26  /neurospin/dico/agaudin/Runs/09_new_repo/Outpu...   0.575591  0.610187
#
#     test_auc  test_intra_auc  best_train_auc  best_val_auc  best_test_auc  \
# 13  0.562972        0.652094        0.602980      0.619958       0.631154
# 14  0.573241        0.591441        0.649106      0.650728       0.588040
# 15  0.511477        0.524631        0.652656      0.631601       0.574902
# 16  0.500755        0.568504        0.575225      0.590644       0.587813
# 17  0.552779        0.634083        0.556991      0.695218       0.515403
# 18  0.528692        0.610837        0.603849      0.612058       0.614089
# 19  0.531863        0.434267        0.602182      0.602911       0.573845
# 20  0.583056        0.607913        0.586292      0.634511       0.478858
# 21  0.591060        0.570967        0.644403      0.623285       0.610692
# 22  0.525445        0.562192        0.698885      0.670270       0.514044
# 23  0.622471        0.632389        0.614145      0.610811       0.606614
# 24  0.427061        0.441195        0.603629      0.602911       0.606841
# 25  0.540169        0.519397        0.723431      0.631185       0.551042
# 26  0.560405        0.567272        0.599961      0.676923       0.532468
#
#     best_test_intra_auc  drop_rate  fusioned_latent_space_size        lr  \
# 13             0.590209   0.065704                          -1  0.002719
# 14             0.592057   0.071718                          -1  0.000222
# 15             0.602217   0.046197                          -1  0.000286
# 16             0.574969   0.042591                          -1  0.005777
# 17             0.606527   0.161732                          -1  0.015171
# 18             0.598830   0.074115                          -1  0.002043
# 19             0.605296   0.028392                          -1  0.004998
# 20             0.514163   0.095888                          -1  0.004190
# 21             0.611761   0.062276                          -1  0.001199
# 22             0.568658   0.054652                          -1  0.001431
# 23             0.609298   0.062589                          -1  0.002203
# 24             0.622845   0.093933                          -1  0.011720
# 25             0.504618   0.068390                          -1  0.004813
# 26             0.576663   0.142079                          -1  0.006037
#
#     max_angle projection_head_name  sigma_noise  train_loss drop_rate_interval
# 13          0              sigmoid     0.037986    1.346405       (0.06, 0.07]
# 14          1              sigmoid     0.291156    0.894474       (0.07, 0.08]
# 15          2              sigmoid     0.406692    1.043118       (0.04, 0.05]
# 16          2              sigmoid     0.019512    1.333641       (0.04, 0.05]
# 17          2              sigmoid     0.432761    1.348774       (0.16, 0.17]
# 18          0              sigmoid     0.067689    1.335534       (0.07, 0.08]
# 19          0              sigmoid     0.005832    1.355917       (0.02, 0.03]
# 20          0              sigmoid     0.010030    1.338901        (0.09, 0.1]
# 21          0              sigmoid     0.018707    1.190995       (0.06, 0.07]
# 22          0              sigmoid     0.062278    0.974331       (0.05, 0.06]
# 23          0              sigmoid     0.003262    1.305248       (0.06, 0.07]
# 24          0              sigmoid     0.043766    1.364846        (0.09, 0.1]
# 25          0              sigmoid     0.076198    1.007713       (0.06, 0.07]
# 26          1              sigmoid     0.202483    1.353748       (0.14, 0.15]

# %%
plt.figure(figsize=(24,6))

plt.subplot(131)
sns.barplot(bdd_activations, y='best_val_auc', x='projection_head_name')

plt.subplot(132)
sns.barplot(bdd_activations, y='best_test_intra_auc', x='projection_head_name')

plt.subplot(133)
sns.barplot(bdd_activations, y='best_test_auc', x='projection_head_name')
# Out:
# <Axes: xlabel='projection_head_name', ylabel='best_test_auc'>
