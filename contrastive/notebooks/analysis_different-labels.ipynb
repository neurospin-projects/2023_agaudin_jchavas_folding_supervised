# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# from scipy.stats import ttest_1samp

# from contrastive.utils.models_database import import_bdd

# %%
import os

def last_part(path):
    return os.sep.join(path.rsplit(r"/")[-2:])

# %% [markdown]
# ## Loads summary dataframe

# %%
database_path = "/volatile/jc225751/Runs/61_classifier_regresser/Output/summary/different-labels.csv"
bdd = pd.read_csv(database_path)

bdd.head()
# Out:
#                 label   auc
# 0           Nb-voxels  0.86
# 1  Nb-voxels-shuffled  0.48
# 2             Flanker  0.54
# 3             Flanker  0.53
# 4             Flanker  0.56

# %%
plt.rc('xtick', labelsize=14) 
plt.rc('ytick', labelsize=14) 
plt.rc('axes', labelsize=18) 
f, ax = plt.subplots(1, 1, figsize=(10, 5))
sns.pointplot(data=bdd, x=bdd.label, y="auc", scale=2,ax=ax)
sns.stripplot(data=bdd, x=bdd.label, y="auc", jitter=0.2, ax=ax)
ax.set_ylim([0.45,0.9])
# Out:
# (0.45, 0.9)
