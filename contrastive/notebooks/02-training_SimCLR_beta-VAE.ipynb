# %% [markdown]
# This notebook contains the code to load the latent spaces of beta-VAE and SimCLR

# %%
import pandas as pd

# %%
src_bVAE = "/neurospin/dico/data/deep_folding/papers/ipmi2023/models/beta-VAE/n_10/#1/cingulate_ACCpatterns_0_embeddings/full_embeddings.csv"
src_SimCLR = "/neurospin/dico/data/deep_folding/papers/ipmi2023/models/contrastive/trained_on_HCP_half_1/gridsearch/joel/convnet-10/23-11-12_0/cingulate_ACCpatterns_0_embeddings/full_embeddings.csv"
dst = "/neurospin/dico/data/deep_folding/papers/ipmi2023/models/fusion/#1/cingulate_ACCpatterns_0_embeddings/full_embeddings.csv"

# %%
bVAE = pd.read_csv(src_bVAE)
SimCLR = pd.read_csv(src_SimCLR)

# %%
fusion = pd.merge(bVAE, SimCLR, left_on='ID', right_on='ID')

# %%
fusion.head()
# Out:
#              ID    dim1_x    dim2_x    dim3_x    dim4_x    dim5_x    dim6_x  \
# 0  1-03HUBJO_t0 -0.534047 -0.173602  2.204910  0.855016 -0.649270  2.034604
# 1  1-08ANDTI_t0  1.547885  1.753840  0.736435  2.264268 -2.081249  0.859171
# 2  1-11LEBJO_t0  1.220122  0.303219  0.953776  2.108884 -1.298484  1.515073
# 3  1-15LEHMI_t0  1.609995 -0.209816  0.181874  0.781753 -0.922371  1.444005
# 4  1-17COLMA_t0  0.456785 -0.849418  0.326016 -0.292699  0.517656  1.647813
#
#      dim7_x    dim8_x    dim9_x  ...     dim1_y    dim2_y     dim3_y  \
# 0 -0.802487 -0.101359  2.125328  ... -14.541647  1.205141 -16.979626
# 1 -0.658971 -0.203598  0.010568  ... -11.723414 -1.325818 -15.058326
# 2 -0.764194 -0.624599  1.678522  ... -12.460865 -2.173624 -15.192888
# 3 -2.564259 -1.393060 -0.754614  ... -13.999170 -1.615181 -10.190755
# 4 -2.295497 -0.458379 -1.511650  ... -15.108498  2.137648 -18.029268
#
#       dim4_y     dim5_y     dim6_y     dim7_y    dim8_y    dim9_y   dim10_y
# ...
