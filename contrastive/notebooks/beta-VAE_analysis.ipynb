# %%
import os
import pandas as pd

# %% [markdown]
# ## Get ACCpatterns0 from ACCpatterns embeddings

# %%
acc0_subjects = pd.read_csv("/neurospin/dico/data/deep_folding/current/datasets/ACCpatterns/ACCpatterns_0.csv", header=None)
acc0_subjects.columns = ['Subject']
acc0_subjects
# Out:
#                               Subject
# 0                    nih_chp_05776_t1
# 1                        e0076_t1_s03
# 2                    nih_chp_05190_t1
# 3                    nih_chp_04910_t1
# 4                    nih_chp_04559_t1
# ..                                ...
# 165  sub-active19_ses-pretraining_T1w
# 166                  nih_chp_05167_t1
# 167                      1-15LEHMI_t0
# 168                  nih_chp_05068_t1
# 169                      e0058_t1_s03
#
# [170 rows x 1 columns]

# %%
def get_acc0_embs(embs_path, acc0_embs_path, acc0_subjects=acc0_subjects):
    embs = pd.read_csv(embs_path, index_col=0)
    acc0_embs = embs[embs.index.isin(acc0_subjects.Subject.values)]
    acc0_embs.sort_index(inplace=True)

    # save the acc0 embeddings
    folder_path = '/' + os.path.join(*acc0_embs_path.split('/')[:-1])
    if not os.path.exists(folder_path):
        os.mkdir(folder_path)
    acc0_embs.to_csv(acc0_embs_path)
    return acc0_embs

# %%
embs_path = "/neurospin/dico/lguillon/collab_joel_aymeric_cingulate/n_4/#1/full_embeddings.csv"
acc0_embs_path = '/' + os.path.join(*embs_path.split('/')[:-1]) + '/cingulate_ACCpatterns_0_embeddings/full_embeddings.csv'

get_acc0_embs(embs_path, acc0_embs_path)
# Out:
# /neurospin/dico/agaudin/Runs/05_rigourous/2022_jchavas_cingulate_inhibitory_control/venv_local/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
#                                           dim1      dim2      dim3      dim4
# ID
# 1-03HUBJO_t0                         -0.781496 -1.622324 -2.660490 -1.042167
# 1-08ANDTI_t0                          0.658339 -0.600490 -0.547822  0.047231
# 1-11LEBJO_t0                          0.531524 -0.587056 -1.522119 -0.882700
# 1-15LEHMI_t0                          0.782463 -1.445667 -0.964990  0.397931
# 1-17COLMA_t0                          1.348191 -1.911520 -1.200599  1.060381
# ...                                        ...       ...       ...       ...
# sub-inhibition17_ses-pretraining_T1w  0.795697 -3.234842 -2.136640  1.169389
# sub-inhibition18_ses-pretraining_T1w -0.466791 -4.025303 -1.692293 -1.319671
# sub-inhibition22_ses-pretraining_T1w  0.517913 -3.578908 -0.589088 -1.298916
# sub-inhibition26_ses-pretraining_T1w  2.270414 -0.942225 -0.489021  1.173676
# sub-inhibition29_ses-pretraining_T1w  1.817151 -1.576319 -0.962080  0.409015
#
# [170 rows x 4 columns]
